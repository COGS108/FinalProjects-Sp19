# %% [markdown]
# # COGS 108 - Final Project

# %% [markdown]
# # Overview

# %% [markdown]
# Our project is focused on finding the relationship between income and health, this would confirm our findings from previous studies we researched. We are attempting to see if low income in households correlates to low health levels in the United States. We will look into how multiple factors, such as one’s socioeconomic status and daily food choices, can create health risk factors such as diabetes and obesity.

# %% [markdown]
# # Names
#
# - Amanda Ochoa
# - Dustin Lamperts
# - Minghan Guo
# - Diana Torres
# - Xiangjian(Aaron) Zeng
# - Jean Hong

# %% [markdown]
# # Group Members IDs
#
# - XXXXXXXXX
# - XXXXXXXXX
# - XXXXXXXXX
# - XXXXXXXXX
# - XXXXXXXXX
# - XXXXXXXXX

# %% [markdown]
# # Research Question

# %% [markdown]
# Are people with low socio-economic status more prone to health issues related to diet, such as diabetes and obesity?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The _American Journal of Clinical Nutrition_ proposes the idea of a causal relation between socioeconomic status and diet quality, which inevitably weighs into the health of one’s life. Living off low wages makes it inevitably harder to access the right food products, which in turn leads to poor choices of food consumption. Nicole Darmon and Adam Drewnowski’s article,  _“Does social class predict diet quality?”_ ,  not only explores the quality of food consumption but also the effects that it has on an individual’s health. Through observations and surveys, Darmon and Drewnowski were able to conclude that lower socioeconomic statuses typically resulted in an energy dense and nutrient poor diet- which refers to products such as hamburgers. This specific food group often leads to overconsumption and catalyzes health risks such as obesity and diabetes. There were also findings that those with a higher socio-economic status were more likely to choose whole grains, vegetables, and fruit. This is probably due to availability of product; whereas people with lower socioeconomic statuses are unable to attain these power foods because of limited accessibility to good product or because it is not affordable. When comparing food prices and diet costs, there was an evident positive correlation between the cost and quality of a product. Therefore, in order to acquire a healthy diet and lifestyle, it is a requirement to attain more money.
#
# Another article that sheds light onto the correlation between socio-economic status and quality of health is in Nancy Adler, W. Thomas Boyce, and other researchers. They mention in, _“Socioeconomic Inequalities in Health: No Easy Solution”_, that throughout history there has been an abundance of records and research that assert the relationships socioeconomic status has had. Their study primarily focused on gathering data about qualities that affect health outcomes across the span of many countries including: the United States and different regions in Europe. The null hypothesis was that socioeconomic status was not a factor in health outcomes and the primary cause of poor was if someone was insured or not. Adler and other researchers proposed that socioeconomic status was the driving factor for poorer health outcomes because of lack of resources and how it can affect an individual’s ability to engage in health promoting and disease preventing behaviors (Adler, 3144). The researchers are able to accept the alternative hypothesis by bringing in their evidence and case studies such as information gathered from Rhode Island. The Rhode Island information gives the following statistics: death rates for wealthier individuals was 10.8 per 1000 while those of a lower socioeconomic status had a death rate of 24.8 per 1000 (Adler, 3140).
#
# Although we agree with Adler and Darmon’s research, we sought out new information to better assert our hypothesis. We wished to find a dataset that was specified to the United States and something closer to our current timeline. This is when we found the Thirty Food Plan. The US Department of Agriculture’s study, Thirty Food Plan, is also mentioned and states that if families with lower incomes bought healthier foods it would take up about 35-40% of their income. 35-40% is a ludicrous amount that no person should have to sacrifice in order to lead a better lifestyle. Therefore, we can present the argument that the driving factor of maintaining a healthy diet is to have a higher socioeconomic status. This method is also a preventative measure against diseases and health risks.
#
# References:
# - 1) Nicole Darmon, Adam Drewnowski, Does social class predict diet quality?, The American Journal of Clinical Nutrition, Volume 87, Issue 5, May 2008, Pages 1107–1117, https://doi.org/10.1093/ajcn/87.5.1107
# - 2) https://jamanetwork.com/journals/jama/articlepdf/406985/jama_269_24_031.pdf

# %% [markdown]
# # Hypothesis

# %% [markdown]
# People with a lower socio-economic status are more likely to develop health issues than those with a higher socioeconomic status. We reason that this is due to a lack of resources for healthier alternatives for food when you have a lower socio-economic status.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: USDA Food Environment Atlas
# - Link to the dataset: https://www.ers.usda.gov/data-products/food-environment-atlas/data-access-and-documentation-downloads/
# - Number of observations: 3143
#
# We are using our dataset from United States Department of Agriculture Economic Research Service (USDA ERS), that was available for the public use. The dataset includes a total of 275 variables with each containing over 3100 observations, divided into 9 different spreadsheets. Each spreadsheet contains  relevant variables and observations that yields to important information about the food accessibility, availability of stores and restaurants nearby, availability of food assistance program (SNAP), food insecurity, taxes on food, availability of local foods, health status, and socio-economic status of people all over the U.S. from different backgrounds. The dataset we are using needs some modification, including data cleaning, merging multiple spreadsheets, and converting to one single csv file.
#
#     Below is a list of variables and detailed descriptions of each variable we used:
# - State
# - County
# - Number of Fast Restaurants per 1000 People
# - Percentage of Black People
# - Percentage of White People
# - Diabetes Rate
# - Obesity Rate
# - Median Income
# - Poverty Rate
# - Number of farmers markets per 1000 people

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (17, 7)
plt.rcParams.update({'font.size': 18})

import seaborn as sns

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

# %% [markdown]
# ### Loading the Data Set
# Instead of importing the entire data set with over 200 variables, we cleaned up the data set first by selecting the variables we wanted and collecting them into one csv file.

# %%
# Import csv file
df = pd.read_csv('data_cleaned.csv')

# %%
df.head()
# Out:
#   State   County  FFRPTH14  PCT_NHWHITE10  PCT_NHBLACK10  \
# 0    AL  Autauga  0.649878      77.246156      17.582599
# 1    AL  Baldwin  0.659634      83.504787       9.308425
# 2    AL  Barbour  0.818239      46.753105      46.691190
# 3    AL     Bibb  0.222163      75.020729      21.924504
# 4    AL   Blount  0.363832      88.887338       1.263040
#
#    PCT_DIABETES_ADULTS13  PCT_OBESE_ADULTS13  MEDHHINC15  POVRATE15  \
# 0                   13.0                34.1     56580.0       12.7
# 1                   10.4                27.4     52387.0       12.9
# 2                   18.4                44.4     31433.0       32.0
# 3                   14.8                40.3     40767.0       22.2
# 4                   14.1                34.6     50487.0       14.7
#
#    FMRKTPTH16
# 0    0.018045
# 1    0.019179
# 2    0.154054
# 3    0.044164
# 4    0.017330

# %%
# Rename columns for easier use
df.columns = (['state', 'county', 'fastfood', 'white', 'black', 'diabetes', 'obesity', 'income', 'poverty', 'farmers_market'])
df.head()
# Out:
#   state   county  fastfood      white      black  diabetes  obesity   income  \
# 0    AL  Autauga  0.649878  77.246156  17.582599      13.0     34.1  56580.0
# 1    AL  Baldwin  0.659634  83.504787   9.308425      10.4     27.4  52387.0
# 2    AL  Barbour  0.818239  46.753105  46.691190      18.4     44.4  31433.0
# 3    AL     Bibb  0.222163  75.020729  21.924504      14.8     40.3  40767.0
# 4    AL   Blount  0.363832  88.887338   1.263040      14.1     34.6  50487.0
#
#    poverty  farmers_market
# 0     12.7        0.018045
# 1     12.9        0.019179
# 2     32.0        0.154054
# 3     22.2        0.044164
# 4     14.7        0.017330

# %%
df.shape
# Out:
# (3143, 10)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# We cleaned the dataset we found online to fit our project’s needs, which consisted of deleting any variables that didn’t have relevance to our project. We decided as a team on which variables were important for our analysis. Because the original file had 9 spreadsheets of data, and most of them were not relevant to our project, we decided to work with 28 out of 275 variables. We used the selected variables to create a new csv file and normalized income variables. We also omitted any null and negative values. Lastly, we limited the years of analysis to 2012-2015 to get the variables that we desired and to get a more relevant sample.

# %%
# Check how many data points have null data in any column'
null_rows = df.isnull().any(axis=1).sum()
null_rows
# Out:
# 4

# %%
# The data set uses "-9999" as a signal for null data
# Find any cells that have this kind of null data
null_rows = df[df.values == "-9999"].any(axis=1).sum()
null_rows
# Out:
# 0

# %%
# Drop any cells that have null data
df = df.dropna()
df.shape
# Out:
# (3139, 10)

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# ## Descriptive Analysis

# %% [markdown]
# We used a scatter_matrix to get a general sense of what variables have larger correlations

# %%
df.describe()
# Out:
#           fastfood        white        black     diabetes      obesity  \
# count  3139.000000  3139.000000  3139.000000  3139.000000  3139.000000
# mean      0.576744    78.360313     8.753403    11.236763    31.015833
# std       0.305546    19.787545    14.426701     2.482565     4.517109
# min       0.000000     2.860408     0.000000     3.300000    11.800000
# 25%       0.413322    67.014549     0.400913     9.500000    28.300000
# 50%       0.578052    85.774059     1.907184    11.100000    31.200000
# 75%       0.732873    94.180771     9.732428    12.900000    33.800000
# max       5.555556    99.163180    85.438778    23.500000    47.600000
#
#               income      poverty  farmers_market
# count    3139.000000  3139.000000     3139.000000
# mean    48611.206117    16.260975        0.058403
# std     12351.988288     6.442319        0.098099
# min     22894.000000     3.400000        0.000000
# 25%     40438.000000    11.500000        0.000000
# ...

# %% [markdown]
# ### Poverty

# %%
# Do a log10 transform of poverty

df['poverty10'] = df['poverty']
df['poverty10'] = df['poverty10'].transform(np.log10)

# Plot histogram of poverty and poverty10

df.hist(['poverty', 'poverty10'], bins=25, grid=False, figsize=(17, 5));

# %% [markdown]
# Poverty rate distribution of Counties 2015: The data in figure one was gathered from a 2015 sample that spanned across the counties of the United States. These counties were used many times throughout the course of this project. This histogram is meant to show the poverty rate distribution throughout the counties, with poverty being measured by who is above or below the average income level in the counties. The majority of the counties lie between 10 and 20% for poverty rate with a very sparse amount going over 30%.

# %% [markdown]
# ### Income

# %%
# Do a log10 transform on income

df['income10'] = df['income']
df['income10'] = df['income10'].transform(np.log10)

df.hist(['income', 'income10'], bins=25, grid=False, figsize=(17, 5));

# %% [markdown]
# A histogram that represents the average income per household across the U.S. in 2015. According to the histogram, most income is distributed within 40,000 to 50,000 US dollars. The histogram is positively skewed because majority of incomes are distributed between 20,000 and 60,000 US dollars while there are very few that are distributed above 60,000 US dollars.

# %% [markdown]
# ### Obesity and Diabetes

# %%
df.hist(['obesity', 'diabetes'], bins=25, grid=False, figsize=(17, 5));

# %% [markdown]
# Figure 4 is a histogram that shows the average rate of adult obesity in 2013 for the same select counties. As shown on the graph, the average adult obesity rate lies between 25% to 35% in these countries, with very few countries having <15% and >45% rate.
#
# The histogram in Fig. 4, shows the average rate of Diabetes in 2013 for the same select counties later in 2015. We are assuming the year differences between the diabetes rate is not drastically different. The average range of diabetes is between 7.5% to 15% in most counties, with a few outliers in other areas. The majority of the populous in U.S counties have an 11% of their people with diabetes. This is considering all populous from different class rankings and different income rates. We are displaying the average obesity rate to compare to the diabetes rate of those in low socioeconomic status that might not have high access to healthy food.

# %%
# Transform the fast food data using a square root transform to make it more normal
df['fastfood10'] = df['fastfood']
df['fastfood10'] = df['fastfood10'].transform(np.sqrt)

# %%
ax_pr=df['fastfood10'].plot.hist(bins=25,title='Number of Fast Food Restaurants per Thousand People by County')
ax_pr.set(xlabel="Number of Fast Food Restaurants per 1000 ppl", ylabel="Counties");

# %% [markdown]
# The histogram shown above, Fig. 5, represents the comparison of number of fast food restaurants and every 1000 people per county. As you can see from the graph, most counties averaged about 0.75 restaurants for every 1000 people. Since it is a uniform distribution, we expect each county to have equal amounts of fast food chains, which will prevent skewed data. We do notice some outlier counties that have a little over half of the average, over 1.5, however we are not worried about this because it looks like a minimal amount. Just by looking at the histogram, we are confident that any data collected and compared with fast food restaurants would be valid.

# %%
df.hist(['white', 'black'], bins=25, grid=False, figsize=(17, 5));

# %% [markdown]
# The histogram on the left shows the distribution of number of black people per county. There are over 1750 counties in the U.S. that have 0 black population.
#
# The graph to the right shows the number of white people per county. As it shows, many counties have a large amount of white people.

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# The largest correlation we found is between income and obesity

# %% [markdown]
# ###  Income and Health
# The most immediate connection that we made in analyzing the data is between diabetes and income. There is more of a connection between income and diabetes than between diabetes and obesity. People can be obese without having diabetes and vice-versa. The correlation factore between diabetes and income is about $-14.66/100 = -0.1466$.
#
# There was a correlation between the percentage of black people in a county and the rate of diabetes, but the distribution for percentage of black people in a county was highly skewed to the left and difficult to normalize. Because of this, we split the data of the black population at the mean, which is 8.753403, using a value of 1.0 for those counties above the mean and 0.0 for those below. We did a scatter plot of diabetes and income with the two colors based on the percentage of black people in each county.

# %%
# Do a linear regression, predicting diabetes from income

outcome, predictors = patsy.dmatrices('diabetes ~ income10', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())

# P-Value: 0
# B_0: 79.7415
# B_1: -14.6562
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               diabetes   R-squared:                       0.370
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     1843.
# Date:                Wed, 12 Jun 2019   Prob (F-statistic):          3.47e-317
# Time:                        11:40:49   Log-Likelihood:                -6582.4
# No. Observations:                3139   AIC:                         1.317e+04
# Df Residuals:                    3137   BIC:                         1.318e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     79.7415      1.596     49.961      0.000      76.612      82.871
# ...

# %%
# Scatter plot of income and diabetes with the best fit line

plt.figure(figsize=(17, 7))
plt.scatter(df['income10'], df['diabetes'])

xs = np.arange(4.2, 5.5)
ys = -14.65621559 * xs + 79.74152135
plt.plot(xs, ys, '--k', linewidth=4)
plt.xlabel('Median Income per County (log10 transformed)')
plt.ylabel('Diabetes Rate per County')
plt.suptitle('Diabetes Rate by Income')
plt.show();

# %% [markdown]
# ## Poverty and Health
# In addition to the relationship between median income and health issues, we wanted to see the link between the poverty rate of a county and the rate of obesity and diabetes. There seems to be a stronger connection between health issues and median income than with poverty rate.

# %% [markdown]
# #### Poverty and obesity

# %%
# Linear regression predicting obesity from poverty

outcome, predictors = patsy.dmatrices('obesity ~ poverty10', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                obesity   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.160
# Method:                 Least Squares   F-statistic:                     599.9
# Date:                Wed, 12 Jun 2019   Prob (F-statistic):          2.20e-121
# Time:                        11:40:49   Log-Likelihood:                -8912.1
# No. Observations:                3139   AIC:                         1.783e+04
# Df Residuals:                    3137   BIC:                         1.784e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.4807      0.517     35.741      0.000      17.467      19.495
# ...

# %%
# Scatter plot of poverty and obesity with linear regression

plt.figure(figsize=(17, 7))
plt.scatter(df['poverty10'], df['obesity'])

xs = np.arange(.5, 2.0)
ys = 10.6371 * xs + 18.4807
plt.plot(xs, ys, '--k', linewidth=4)
plt.xlabel('Poverty Rate')
plt.ylabel('Obesity Rate')
plt.show()

# %% [markdown]
# There is a positive correlation between poverty rate and obesity rate among counties.
#
# $R^2 = 0.161$
#
# $\text{Adj. } R^2 = 0.160$
#
# $P = 0$
#
# $B_0 = 18.4807$
#
# $B_1 = \frac{10.6371}{100} = 0.106371$

# %% [markdown]
# #### Poverty and Diabetes

# %%
outcome, predictors = patsy.dmatrices('diabetes ~ poverty10', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               diabetes   R-squared:                       0.287
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     1264.
# Date:                Wed, 12 Jun 2019   Prob (F-statistic):          7.47e-233
# Time:                        11:40:50   Log-Likelihood:                -6776.6
# No. Observations:                3139   AIC:                         1.356e+04
# Df Residuals:                    3137   BIC:                         1.357e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.0236      0.262      7.727      0.000       1.510       2.537
# ...

# %%
plt.figure(figsize=(17, 7))

plt.scatter(df['poverty10'], df['diabetes'])

xs = np.arange(.5, 2)
ys = 7.8182 * xs + 2.0236
plt.plot(xs, ys, '--k', linewidth=4)
plt.xlabel('Poverty Rate')
plt.ylabel('Diabetes Rate')
plt.suptitle('Poverty and Diabetes')
plt.show()

# %% [markdown]
# There is a positive correlation between poverty rate and diabetes rate among counties.
#
# $R^2 = 0.287$
#
# $\text{Adj. } R^2 = 0.287$
#
# $P = 0$
#
# $B_0 = 2.0236$
#
# $B_1 = \frac{7.8182}{100} = .078182$

# %% [markdown]
# ## Distribution by race
# In addition to exploring the relationship between income and health, we wanted to look into the relationship between race and health. When we looked at the percentage of white people in a county with the rate of diabetes, there was no strong correlation between the two. Communities with all percentages of white people had more or less even distribution of diabetes across counties.
#
# When we looked at the percentage of black people per county, however, there were higher rates of diabetes and obesity among counties with higher percentages of black people. Since we found a relationship between median income and health issues, we wanted to look for confounding variables, specifically, what factors might account for the link between income and health. When we see a link between race and health issues, it might help us to do more research in the future to see causal relationships between such factors.

# %%
plt.figure(figsize = (17, 7))
plt.scatter(df['white'], df['diabetes'])
plt.scatter(df['white'], df['obesity'])
plt.xlabel('White People')
plt.ylabel('Health')
plt.legend()
plt.suptitle('Percentage of White People and Health');

# %% [markdown]
# The distribution of health issues is more or less uniformly distributed accross counties based on the percentage of white people per county. There are generally higher rates of obesity than diabetes accross the board.

# %%
plt.figure(figsize=(17, 7))
plt.scatter(df['black'], df['obesity'])
plt.scatter(df['black'], df['diabetes'])
plt.xlabel('Percentage of Black People')
plt.ylabel('Health')
plt.suptitle('Percentage of Black People and Health')
plt.legend()
plt.show();

# %% [markdown]
# There is a pretty even distribution of health issues accross counties that have a low percentage of black people, but as the percentage of black people in a county rises, there is a clear trend towards predominantly higher rates of obesity and diabetes. This shows that these health issues seems to disproportionately affect black communities.

# %%
plt.figure(figsize=(17, 7))
plt.scatter(df['black'], df['income10'])
plt.scatter(df['white'], df['income10'])
plt.ylabel('Income')
plt.legend()
plt.suptitle('Income distribution Accross White and Black Communities')
plt.show();

# %% [markdown]
# There are certainly counties with high populations of white people that have a low median income, but as the percentage of black people in county increases, the median income trends downwards. There are counties that have a higher population of black people along with a higher income, but those counties are more outliers than the normal trend.

# %% [markdown]
# ### Health and Food Availability
# Surprisingly, the data shows that there is little correlation between the availability of certain types of food and the health of the people in a county. The rate of diabetes is pretty evenly distributed among counties that have no fast food restaurants so we dropped counties with zero fast food restaurants as well as couple of outliers above 1.5 fast food restaurants per 1000 people.

# %%
# The rate of diabetes related to the availability of farmers' markets

df.plot.scatter('farmers_market', 'diabetes', figsize=(17, 7));

# %% [markdown]
# The rate of diabetes is pretty evenly distributed across the number of farmer's markets per thousand people by county. There are a few outliers with much higher numbers of farmer's markets, but they don't have the lowest rate of diabetes. The counties with the highest rates of diabetes also don't have the lowest number of farmer's markets.

# %%
# Create new data frame with 
# Drop rows with zero fast food restaurants
df2 = df[df['fastfood'] > 0]
df2 = df2[df2['fastfood'] < 1.5]

df.plot.scatter('fastfood', 'diabetes', figsize=(17, 4))
df2.plot.scatter('fastfood', 'diabetes', figsize=(17, 4));

# %% [markdown]
# There is very little correlation between the availability of fast food restaurants and health issues. Even after removing counties with zero fast food restaurants and outliers with more than 1.5 fast food restaurants per 1000 people, the correlation is very low.

# %% [markdown]
# ## Race, Income, and Health
# After looking into the relationship between income and health, we wanted to see if there were any confounding variables that might account for why those with lower incomes were more likely to have health issues. When we looked at race, it seemed that communities with higher percentages of black people also had higher rates of diabetes and obesity. Looking at income and race together, we found a stronger correlation with health issues than any predictor individually.

# %%
# Define function that splits percentage of black people per county

def split_by_mean(percentage):
    """
        Assigns value of 1.0 to counties with a black population above mean
        and value of 0.0 to counties below the mean.
    """
    if percentage < 8.753403:
        return 0.0
    else:
        return 1.0
    
df['black_split'] = [split_by_mean(percent) for percent in df['black']]

# %%
# Linear regression prediction diabetes rate from income and black population

outcome, predictors = patsy.dmatrices('diabetes ~ income10 + black_split', df)
mod = sm.OLS(outcome, predictors)
res = mod.fit()
print(res.summary())

# P-Value: 0
# B_0: 74.2981
# B_1: -13.5644
# B_2: 1.2704
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               diabetes   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     1133.
# Date:                Wed, 12 Jun 2019   Prob (F-statistic):               0.00
# Time:                        11:40:53   Log-Likelihood:                -6454.5
# No. Observations:                3139   AIC:                         1.291e+04
# Df Residuals:                    3136   BIC:                         1.293e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      74.2981      1.568     47.371      0.000      71.223      77.373
# ...

# %%
sns.scatterplot(x='income10', y='diabetes', hue='black_split', data=df, alpha=.5);

# %% [markdown]
# The distribution of diabetes accross income levels showing counties with percentage of black people above the mean (8.753403) in orange and those below the mean in blue.
#
# $R^2 = 0.419$
#
# $Adj.  R^2 = 0.419$
#
# $P_{value} = 0$
#
# $B_0 = 74.2981$
#
# $B_1 = -13.5644$
#
# $B_2 = 1.2704$

# %%
# plot with regression line
sns.lmplot(x='income10', y='diabetes', hue='black_split', data=df, ci=None, aspect=2.5);

# %% [markdown]
# Counties that have a percentage of black people higher than the mean tend to have a higher rate of diabetes at lower median incomes that counties that are below the mean. Counties with largely lower income black populations are disproportionately susceptible to obesity and diabetes. There are still factors that could be confounding variables that were not available in the data that we used. For example, even counties with higher accessibility to fast food did not have such high rates of health issues, so just having access was not as much of a contributor. There might be other variables such as education and awareness of healthy practices that are affecting predominantly black communities more than others.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The data was published for the public use by the United States Department of Agriculture. Since the data was released publicly it is accessible for us to use without limitations. The data was gathered with the knowledge and consent of participants, who were made aware of potential future uses of the data gathered. Our goal in analyzing this data is to help spread awareness of the lack of access to healthy food for people with lower socioeconomic status and to help increase access to healthy food for those people. By this we are not making the claim that all people in a low socioeconomic class are unhealthy but rather trying to see if there is a correlation in the majority of the population. We are also analyzing the correlation between race, income, and health as the population in counties are important to consider for access to different foods. Race is only used to find the correlation between different county areas and their access to food resources.
#
# The data originally gathered was meant to assemble statistics on food environment indicators; to view the determinants of food choices and diet quality. It was also meant to provide an overview of community's ability to access healthy food. If there was a bias in the conduction of the original data then our data collection might have been affected. Since we are using this data to find correlations between socioeconomic status, race and health our analysis should not have been affected by the way the data was gathered, unless the original data was biased. To limit the amount of bias towards certain states or groups we focused on income and health  in a variety of states and their access to certain foods/ resources.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# This project aimed to observe the relationship between socioeconomic status and health. We predicted that people with low socioeconomic status will be more prone to health issues such as diabetes and obesity due to lack of access to healthy food choices. To test our hypothesis, we looked at the distribution of fast food restaurants and farmers markets across different socioeconomic status and prevalence rate of diabetes and obesity across the United States. We speculated that the availability of fast food restaurants and farmers market will influence one’s food choices. Our results show that there is a strong correlation between socioeconomic status and health, as people from lower socioeconomic status had higher diabetes and obesity rate. However, the food choices does not seem to influence the high rates of health issues because both fast food restaurants and farmers markets were equally largely distributed across all socioeconomic statuses.
#
# **Limitations:** As with any project, we encountered some limitations through the duration of these past 10 weeks. One of the limitations we had was that our variables were not consistent throughout the three years of analysis. For example, when we were correlating the poverty rate versus obesity rate, the poverty rate variable was extracted from data in 2015 and obesity data was taken from 2013. However, we would assume that this information was fixed and generalized to the other years of analysis. Also, to measure one’s food choices, we measured the distribution of restaurants in different socioeconomic statuses. We had to make an assumption that the distribution of different restaurants and grocery stores translates to different food choices, instead of actually measuring the food choices across socioeconomic statuses. Although the distribution of restaurants and grocery stores can predict one’s food choices, it does not directly translate to one’s food choices and consumption. Another problem we had when gathering our data was attaining a large enough dataset with variables that matched our hypothesis and research question. Since we are students we only have a limited access to sources, in comparison to real life data scientists who can choose from a plethora of data.
#
# **Confounding variables:** Through the duration of this project we assumed that there would be a correlation with fast food consumption, which was measured by number of sales, and income. However, what we later found was that fast food was equally consumed through all levels of income. This could have hindered our original hypothesis which we worried about. Another possible confounding finding was discovered when we became curious of the relationship between race and health risks such as obesity and diabetes. The data showed that African Americans are more likely to develop these unhealthy risk factors across the board despite the socio-economic status. However, this was not true for the caucasion population. We believe that race is a confounding variable because it can skew the data. Instead of socio-economic status being the driving factor for being at health risk, we now see that race plays a more important role.
