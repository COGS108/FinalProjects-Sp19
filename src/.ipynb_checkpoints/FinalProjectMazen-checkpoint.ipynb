# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
#read the pfac data, which shows the actual police control area of the county
pfac = pd.read_csv('../data/PFAC.csv')

#read the scenery data 
df = pd.read_csv('scenery.csv', encoding = "ISO-8859-1")
print('Size of the dataset: ' + str(df.shape[0]))

#switch the colomns and rows for pfac data
pfac = pfac.transpose()
pfac.reset_index(inplace = True)

#reset the header of the pfac data
new_header = pfac.iloc[0]
pfac = pfac[1:]
pfac.columns = new_header

#read the crime data
crime_df = pd.read_csv('../data/number_crime.csv')

#make list of crime data's column names
cols = list(crime_df)

#remove all commas from the numbers
crime_df[cols] = crime_df[cols].replace(',', '', regex = True)

print(pfac.shape[1])
# Out:
# Size of the dataset: 212155
# 43

# %%
#find the county
def matchCounty(area):
    for i in pfac.columns:
        if area in list(pfac[i]):
            return i
    return np.nan

# %%
#the unique
len(df['County'].unique())
# Out:
# 214

# %%
#df['County'].unique()

# %%
df['County'] = df['County'].apply(matchCounty)
len(df['County'].unique())
# Out:
# 44

# %%
sum(df['County'].isnull())
# Out:
# 65530

# %%
#df['County'].unique()

# %%
#df['County'].head(100)

# %% [markdown]
# ##### comment
# drop every column except 'County' and 'Rating'
#
# calculate avg_rating and standard_deviation from 'Rating' and add 'num_pictures'

# %%
import statistics

df_rate = df.drop(columns=['ID', 'Place', 'Variance', 'Near', 'Category', 'Image', 'Date', 'URL'])
df_rate = df_rate.dropna()
df_rate['Avg_Rating'] = df_rate['Rating']
df_rate['Standard_Deviation'] = df_rate['Rating']
df_rate = df_rate.drop(columns=['Rating'])
df_rate['num_pictures'] = 1


aggregation_functions = {'Avg_Rating': 'mean', 'Standard_Deviation': 'std', 'num_pictures': 'sum'}
df_rate_mean = df_rate.groupby(df_rate['County']).aggregate(aggregation_functions)
df_rate_mean
# Out:
#                      Avg_Rating  Standard_Deviation  num_pictures
# County
# Avon and Somerset      2.712359            1.873534          4755
# Bedfordshire           2.548122            1.870577          1187
# Cambridgeshire         2.462462            1.848670          3209
# Cheshire               2.526800            1.835459          2296
# City of London         3.209225            1.974855             4
# Cleveland              2.363048            1.900951           299
# Cumbria                2.908924            1.928069          6869
# Derbyshire             2.706742            1.929414          2558
# Devon and Cornwall     2.788292            1.834246         10616
# Dorset                 2.678697            1.826376          2707
# Durham                 2.698612            1.863479          2367
# Dyfed-Powys            2.876897            1.834040          6096
# Essex                  2.471854            1.831060          3708
# Gloucestershire        2.714484            1.846298          2642
# Greater Manchester     2.428156            2.068918          1192
# Gwent                  2.581222            1.935530           591
# Hampshire              2.600870            1.840056          4187
# Hertfordshire          2.451411            1.895379          1648
# Humberside             2.557852            1.787980          3532
# Kent                   2.503552            1.787717          3851
# Lancashire             2.600273            1.893096          3016
# Leicestershire         2.519469            1.785538          2449
# Lincolnshire           2.534675            1.809087          5732
# Merseyside             2.445716            2.039121           681
# Metropolitan Police    1.938014            1.907292          1284
# Norfolk                2.633350            1.841184          5314
# North Wales            2.941677            1.979406          6228
# North Yorkshire        2.771272            1.866603          8073
# Northamptonshire       2.575889            1.846145          2272
# Northumbria            2.821843            1.893762          5257
# Nottinghamshire        2.464685            1.880608          2087
# South Wales            2.692996            1.855747          6290
# South Yorkshire        2.287032            1.763057          1431
# Staffordshire          2.560061            1.869428          2608
# Suffolk                2.623217            1.822361          3796
# Surrey                 2.633970            1.971105          1624
# Sussex                 2.723256            1.860760          3694
# Thames Valley          2.566494            1.820355          5558
# Warwickshire           2.517741            1.825380          1873
# West Mercia            2.654227            1.812546          4838
# West Midlands          2.468773            1.809740          2968
# West Yorkshire         2.538564            1.946999          1921
# Wiltshire              2.692212            1.848735          3317

# %%
df_rate_mean['Avg_Rating'].plot(figsize=(15, 5),kind='bar')

# %%
map_df = gpd.read_file("../../PFA Geospatial Analysis Stuff/Police_Force_Areas_December_2016_Full_Extent_Boundaries_in_England_and_Wales.shp")
map_df.head()
# Out:
#    objectid    pfa16cd              pfa16nm   bng_e   bng_n     long  \
# 0         1  E23000001  Metropolitan Police  517516  178392 -0.30864
# 1         2  E23000002              Cumbria  341868  527389 -2.90218
# 2         3  E23000003           Lancashire  363669  441026 -2.55392
# 3         4  E23000004           Merseyside  344324  390164 -2.83893
# 4         5  E23000005   Greater Manchester  377940  401102 -2.33407
#
#          lat    st_areasha     st_lengths  \
# 0  51.492271  1.591548e+09  265949.573309
# 1  54.638260  7.182473e+09  580153.739027
# 2  53.864182  3.263181e+09  405501.205090
# 3  53.405350  8.175714e+08  276339.477012
# 4  53.506149  1.275981e+09  248705.576852
#
#                                             geometry
# 0  POLYGON ((531643.5972999996 200802.7000999991,...
# 1  POLYGON ((357067.4968999997 586765.5993000008,...
# 2  POLYGON ((370171.7023 482434.6038000006, 37018...
# 3  POLYGON ((337343.2988999998 422097.6950000003,...
# 4  POLYGON ((391363.1005999995 420849.9022000004,...

# %%
merged = map_df.set_index("pfa16nm").join(crime_df.set_index("Area Name"))
merged = merged.join(df_rate_mean)
merged
# Out:
#                      objectid    pfa16cd   bng_e   bng_n      long        lat  \
# pfa16nm
# Metropolitan Police         1  E23000001  517516  178392 -0.308640  51.492271
# Cumbria                     2  E23000002  341868  527389 -2.902180  54.638260
# Lancashire                  3  E23000003  363669  441026 -2.553920  53.864182
# Merseyside                  4  E23000004  344324  390164 -2.838930  53.405350
# Greater Manchester          5  E23000005  377940  401102 -2.334070  53.506149
# Cheshire                    6  E23000006  368759  368676 -2.469270  53.214230
# Northumbria                 7  E23000007  398898  602530 -2.018920  55.316841
# Durham                      8  E23000008  410381  532242 -1.840500  54.685131
# North Yorkshire             9  E23000009  429509  466515 -1.550320  54.093712
# West Yorkshire             10  E23000010  418686  427238 -1.718170  53.741199
# South Yorkshire            11  E23000011  441052  398663 -1.382840  53.483109
# Humberside                 12  E23000012  488051  443608 -0.662030  53.881222
# Cleveland                  13  E23000013  445425  522495 -1.298480  54.595612
# West Midlands              14  E23000014  402507  289715 -1.964480  52.505341
# Staffordshire              15  E23000015  398243  334651 -2.027560  52.909302
# West Mercia                16  E23000016  366411  287999 -2.496090  52.488869
# Warwickshire               17  E23000017  429584  253588 -1.568740  52.179771
# Derbyshire                 18  E23000018  426752  353556 -1.602100  53.078579
# Nottinghamshire            19  E23000019  466570  359496 -1.006560  53.128502
# Lincolnshire               20  E23000020  517985  358543 -0.238820  53.111050
# Leicestershire             21  E23000021  466555  310191 -1.016860  52.685349
# Northamptonshire           22  E23000022  477359  268708 -0.866680  52.311050
# Cambridgeshire             23  E23000023  536856  271834  0.006854  52.327549
# Norfolk                    24  E23000024  600546  312278  0.964662  52.671108
# Suffolk                    25  E23000025  608216  266122  1.049148  52.253868
# Bedfordshire               26  E23000026  508276  242055 -0.421840  52.066299
# Hertfordshire              27  E23000027  518883  213642 -0.276990  51.808788
# Essex                      28  E23000028  569523  210837  0.455548  51.770538
# Thames Valley              29  E23000029  462576  202253 -1.095610  51.715519
# Hampshire                  30  E23000030  445931  135667 -1.345130  51.118450
# Surrey                     31  E23000031  515966  153408 -0.339110  51.268028
# Kent                       32  E23000032  590108  148050  0.719768  51.200020
# Sussex                     33  E23000033  556566  117293  0.226790  50.933830
# City of London             34  E23000034  532382  181358 -0.093510  51.515640
# Devon and Cornwall         35  E23000035  249986   81319 -4.121670  50.612228
# Avon and Somerset          36  E23000036  356387  150272 -2.626270  51.249931
# Gloucestershire            37  E23000037  389595  213465 -2.152350  51.819710
# Wiltshire                  38  E23000038  405209  158863 -1.926610  51.328831
# Dorset                     39  E23000039  375742   99796 -2.345560  50.797199
# North Wales                40  W15000001  282470  346124 -3.752750  52.999512
# Gwent                      41  W15000002  331785  205411 -2.989400  51.743229
# South Wales                42  W15000003  291642  190822 -3.566100  51.605782
# Dyfed-Powys                43  W15000004  290528  263540 -3.605330  52.259110
#
#                        st_areasha    st_lengths  \
# pfa16nm
# Metropolitan Police  1.591548e+09  2.659496e+05
# Cumbria              7.182473e+09  5.801537e+05
# Lancashire           3.263181e+09  4.055012e+05
# Merseyside           8.175714e+08  2.763395e+05
# Greater Manchester   1.275981e+09  2.487056e+05
# Cheshire             2.380270e+09  3.481666e+05
# Northumbria          5.628936e+09  6.153299e+05
# Durham               2.430174e+09  3.333017e+05
# North Yorkshire      8.324956e+09  7.330288e+05
# West Yorkshire       2.029259e+09  2.828896e+05
# South Yorkshire      1.552093e+09  2.519536e+05
# Humberside           3.655532e+09  5.359161e+05
# Cleveland            6.166170e+08  1.857764e+05
# West Midlands        9.016397e+08  2.564299e+05
# Staffordshire        2.716763e+09  4.381221e+05
# West Mercia          7.407813e+09  8.135307e+05
# Warwickshire         1.977523e+09  3.975703e+05
# Derbyshire           2.628794e+09  4.191313e+05
# Nottinghamshire      2.161509e+09  3.033395e+05
# Lincolnshire         6.102769e+09  5.582702e+05
# Leicestershire       2.550878e+09  3.427321e+05
# Northamptonshire     2.366990e+09  3.804078e+05
# Cambridgeshire       3.397445e+09  4.282525e+05
# Norfolk              5.508350e+09  4.450390e+05
# Suffolk              3.853575e+09  4.482343e+05
# Bedfordshire         1.235426e+09  2.465212e+05
# Hertfordshire        1.643065e+09  3.028915e+05
# Essex                3.947528e+09  5.876591e+05
# Thames Valley        5.743410e+09  5.838109e+05
# Hampshire            4.249365e+09  5.742445e+05
# Surrey               1.670073e+09  2.735882e+05
# Kent                 3.908616e+09  3.820506e+05
# Sussex               3.834009e+09  3.968269e+05
# City of London       3.149382e+06  9.601694e+03
# Devon and Cornwall   1.047622e+10  1.467275e+06
# Avon and Somerset    5.027766e+09  5.802081e+05
# Gloucestershire      2.704529e+09  4.249608e+05
# Wiltshire            3.485431e+09  3.870170e+05
# Dorset               2.694858e+09  4.084569e+05
# North Wales          6.364478e+09  8.861284e+05
# Gwent                1.616177e+09  3.017852e+05
# South Wales          2.153374e+09  3.543409e+05
# Dyfed-Powys          1.109074e+10  1.161140e+06
#
#                                                               geometry  \
# pfa16nm
# Metropolitan Police  POLYGON ((531643.5972999996 200802.7000999991,...
# Cumbria              POLYGON ((357067.4968999997 586765.5993000008,...
# Lancashire           POLYGON ((370171.7023 482434.6038000006, 37018...
# Merseyside           POLYGON ((337343.2988999998 422097.6950000003,...
# Greater Manchester   POLYGON ((391363.1005999995 420849.9022000004,...
# Cheshire             POLYGON ((367308.2007999998 398265.4968999997,...
# Northumbria          (POLYGON ((398210.8958999999 657405.5988999996...
# Durham               POLYGON ((416954.8963000001 558226.7984999996,...
# North Yorkshire      POLYGON ((478789.5977999996 519220.1040000003,...
# West Yorkshire       POLYGON ((407885.5022 451894.6956999991, 40794...
# South Yorkshire      POLYGON ((466825.4040000001 418565.8959999997,...
# Humberside           POLYGON ((505320.8026999999 476615.7993999999,...
# Cleveland            POLYGON ((447213.8995000003 537036.1042999998,...
# West Midlands        POLYGON ((403327.4016000004 307057.8048999999,...
# Staffordshire        POLYGON ((402840.4978 368845.5983000007, 40286...
# West Mercia          POLYGON ((374571.2999 344603.2975999992, 37457...
# Warwickshire         POLYGON ((428696.4982000003 309045.1960000005,...
# Derbyshire           POLYGON ((409407.5981999999 404118.1017000005,...
# Nottinghamshire      POLYGON ((471406.2033000002 400279.2005000003,...
# Lincolnshire         POLYGON ((512572.5977999996 414469.4986000005,...
# Leicestershire       POLYGON ((481679.3020000001 342838.1029000003,...
# Northamptonshire     POLYGON ((500812.7991000004 306101.6985999998,...
# Cambridgeshire       POLYGON ((546710.3992999997 317809.0973000005,...
# Norfolk              (POLYGON ((591658.9023000002 347540.3969000001...
# Suffolk              POLYGON ((650202.9999000002 300815.7017000001,...
# Bedfordshire         POLYGON ((505548.5972999996 270000.0025999993,...
# Hertfordshire        POLYGON ((526369.9984999998 244045.7018999998,...
# Essex                POLYGON ((583950.7018999998 246574.2981000002,...
# Thames Valley        POLYGON ((490173.6030999999 256107.9990999997,...
# Hampshire            (POLYGON ((463950.5985000003 165127.1020999998...
# Surrey               POLYGON ((503199.2989999996 175411.0984000005,...
# Kent                 POLYGON ((585973.8008000003 181262.8033000007,...
# Sussex               POLYGON ((527526.3022999996 142467.1984000001,...
# City of London       POLYGON ((532140.2961999997 182191.8973999992,...
# Devon and Cornwall   (POLYGON ((275492.9978 151239.5974000003, 2755...
# Avon and Somerset    POLYGON ((364892.0021000002 196487.4953000005,...
# Gloucestershire      POLYGON ((416361.7960999999 245471.0039000008,...
# Wiltshire            POLYGON ((413379.9038000004 199478.1992000006,...
# Dorset               POLYGON ((377927.9961999999 131215.0993000008,...
# North Wales          (POLYGON ((312661.6013000002 385723.0972000007...
# Gwent                (POLYGON ((327830.7988 231005.1046999991, 3278...
# South Wales          (POLYGON ((303435.5016000001 214925.5974000003...
# Dyfed-Powys          (POLYGON ((322392.9007000001 334017.1977999993...
#
#                     Total recorded crime (excluding fraud)     ...       \
# pfa16nm                                                        ...
# Metropolitan Police                                 835078     ...
# Cumbria                                              35372     ...
# Lancashire                                          162819     ...
# Merseyside                                          134164     ...
# Greater Manchester                                  334976     ...
# Cheshire                                             94201     ...
# Northumbria                                         160292     ...
# Durham                                               62393     ...
# North Yorkshire                                      43762     ...
# West Yorkshire                                      291573     ...
# South Yorkshire                                     142739     ...
# Humberside                                           98311     ...
# Cleveland                                            65397     ...
# West Midlands                                       252689     ...
# Staffordshire                                        84765     ...
# West Mercia                                          84554     ...
# Warwickshire                                         41304     ...
# Derbyshire                                           59162     ...
# Nottinghamshire                                     104112     ...
# Lincolnshire                                         48582     ...
# Leicestershire                                       87167     ...
# Northamptonshire                                     58632     ...
# Cambridgeshire                                       63678     ...
# Norfolk                                              58972     ...
# Suffolk                                              54124     ...
# Bedfordshire                                         55173     ...
# Hertfordshire                                        85371     ...
# Essex                                               151103     ...
# Thames Valley                                       162070     ...
# Hampshire                                           159487     ...
# Surrey                                               74745     ...
# Kent                                                197085     ...
# Sussex                                              114049     ...
# City of London                                        6921     ...
# Devon and Cornwall                                  106616     ...
# Avon and Somerset                                   135955     ...
# Gloucestershire                                      35292     ...
# Wiltshire                                            42483     ...
# Dorset                                               53099     ...
# North Wales                                          58184     ...
# Gwent                                                56497     ...
# South Wales                                         108729     ...
# Dyfed-Powys                                          26694     ...
#
#                     Shoplifting  Other theft offences  \
# pfa16nm
# Metropolitan Police       43743                114092
# Cumbria                    2899                  3210
# Lancashire                 9476                 16378
# Merseyside                 8645                 10633
# Greater Manchester        17352                 32096
# Cheshire                   7084                  7712
# Northumbria               14081                 16832
# Durham                     4862                  5357
# North Yorkshire            4448                  4706
# West Yorkshire            18714                 25639
# South Yorkshire           10834                 14326
# Humberside                10356                  8460
# Cleveland                  8867                  6349
# West Midlands             18774                 24763
# Staffordshire              7414                  9238
# West Mercia                7713                  9052
# Warwickshire               3422                  4416
# Derbyshire                 5851                  6472
# Nottinghamshire           10983                 11511
# Lincolnshire               5524                  5058
# Leicestershire             6647                  9234
# Northamptonshire           4104                  5630
# Cambridgeshire             5041                  7315
# Norfolk                    4151                  5639
# Suffolk                    4148                  4729
# Bedfordshire               3966                  5466
# Hertfordshire              8607                  8775
# Essex                     10721                 13579
# Thames Valley             14256                 20782
# Hampshire                 12969                 13559
# Surrey                     4347                  9080
# Kent                      12700                 16994
# Sussex                     7983                 12608
# City of London              902                  1680
# Devon and Cornwall         7725                 10742
# Avon and Somerset         10663                 13592
# Gloucestershire            3373                  3865
# Wiltshire                  4300                  4479
# Dorset                     4046                  6417
# North Wales                4204                  5131
# Gwent                      3633                  4742
# South Wales               10495                 10183
# Dyfed-Powys                1938                  3089
#
#                     Criminal damage and arson Drug offences  \
# pfa16nm
# Metropolitan Police                     56537         35474
# Cumbria                                  5458          1022
# Lancashire                              20238          2342
# Merseyside                              16328          8181
# Greater Manchester                      35821          4981
# Cheshire                                10162          2180
# Northumbria                             22742          3344
# Durham                                   9585          1269
# North Yorkshire                          5993          1563
# West Yorkshire                          31094          6303
# South Yorkshire                         18045          2490
# Humberside                              12809          1374
# Cleveland                                9370          1298
# West Midlands                           25695          4558
# Staffordshire                           10971          1816
# West Mercia                             10037          2024
# Warwickshire                             4520           839
# Derbyshire                               7872          2237
# Nottinghamshire                         12129          3259
# Lincolnshire                             6084          1778
# Leicestershire                          10300          1867
# Northamptonshire                         6619          1577
# Cambridgeshire                           7491          1325
# Norfolk                                  7083          2300
# Suffolk                                  6520          1290
# Bedfordshire                             6101          1343
# Hertfordshire                            9216          3148
# Essex                                   15910          3743
# Thames Valley                           19104          5065
# Hampshire                               18549          3682
# Surrey                                   9457          2853
# Kent                                    22359          3043
# Sussex                                  13767          3483
# City of London                            232           425
# Devon and Cornwall                      14527          3982
# Avon and Somerset                       15487          2876
# Gloucestershire                          4456           959
# Wiltshire                                5709          1044
# Dorset                                   6861          1609
# North Wales                              7586          1352
# Gwent                                    9121          1390
# South Wales                             12787          4197
# Dyfed-Powys                              4042          1816
#
#                     Possession of weapons offences  Public order offences  \
# pfa16nm
# Metropolitan Police                           7401                  48281
# Cumbria                                        252                   3084
# Lancashire                                     701                  14938
# Merseyside                                    1033                  12689
# Greater Manchester                            3542                  45151
# Cheshire                                       532                  17976
# Northumbria                                   1392                  23401
# Durham                                         290                   5141
# North Yorkshire                                309                   2210
# West Yorkshire                                2314                  28213
# South Yorkshire                               1377                  12632
# Humberside                                     509                   8395
# Cleveland                                      377                   3836
# West Midlands                                 2281                  13918
# Staffordshire                                  801                   4258
# West Mercia                                    809                   4249
# Warwickshire                                   412                   2194
# Derbyshire                                     593                   2225
# Nottinghamshire                                954                   6807
# Lincolnshire                                   525                   2767
# Leicestershire                                 740                   6638
# Northamptonshire                               614                   2249
# Cambridgeshire                                 534                   4177
# Norfolk                                        580                   5496
# Suffolk                                        450                   5075
# Bedfordshire                                   415                   3601
# Hertfordshire                                  715                   6466
# Essex                                         2099                  12222
# Thames Valley                                 1419                   6848
# Hampshire                                     1621                  14894
# Surrey                                         585                   7526
# Kent                                          1335                  21115
# Sussex                                        1598                  10203
# City of London                                  72                    412
# Devon and Cornwall                             932                   7151
# Avon and Somerset                              782                  17450
# Gloucestershire                                246                   1413
# Wiltshire                                      305                   2710
# Dorset                                         323                   3003
# North Wales                                    331                   5018
# Gwent                                          214                   7621
# South Wales                                    667                  11238
# Dyfed-Powys                                    179                   1651
#
#                     Miscellaneous crimes Avg_Rating Standard_Deviation  \
# pfa16nm
# Metropolitan Police                 9876   1.938014           1.907292
# Cumbria                              717   2.908924           1.928069
# Lancashire                          3241   2.600273           1.893096
# Merseyside                          2752   2.445716           2.039121
# Greater Manchester                  8262   2.428156           2.068918
# Cheshire                            1842   2.526800           1.835459
# Northumbria                         3728   2.821843           1.893762
# Durham                              1735   2.698612           1.863479
# North Yorkshire                      812   2.771272           1.866603
# West Yorkshire                      7461   2.538564           1.946999
# South Yorkshire                     3837   2.287032           1.763057
# Humberside                          2429   2.557852           1.787980
# Cleveland                           1372   2.363048           1.900951
# West Midlands                       3682   2.468773           1.809740
# Staffordshire                       1888   2.560061           1.869428
# West Mercia                         1515   2.654227           1.812546
# Warwickshire                         723   2.517741           1.825380
# Derbyshire                          1241   2.706742           1.929414
# Nottinghamshire                     2370   2.464685           1.880608
# Lincolnshire                        1095   2.534675           1.809087
# Leicestershire                      1923   2.519469           1.785538
# Northamptonshire                    1118   2.575889           1.846145
# Cambridgeshire                      1330   2.462462           1.848670
# Norfolk                             1675   2.633350           1.841184
# Suffolk                             1064   2.623217           1.822361
# Bedfordshire                         975   2.548122           1.870577
# Hertfordshire                       1777   2.451411           1.895379
# Essex                               3285   2.471854           1.831060
# Thames Valley                       3308   2.566494           1.820355
# Hampshire                           2650   2.600870           1.840056
# Surrey                              1564   2.633970           1.971105
# Kent                                5305   2.503552           1.787717
# Sussex                              2283   2.723256           1.860760
# City of London                       129   3.209225           1.974855
# Devon and Cornwall                  2195   2.788292           1.834246
# Avon and Somerset                   1779   2.712359           1.873534
# Gloucestershire                      442   2.714484           1.846298
# Wiltshire                            737   2.692212           1.848735
# Dorset                               682   2.678697           1.826376
# North Wales                         1262   2.941677           1.979406
# Gwent                               1362   2.581222           1.935530
# South Wales                         2099   2.692996           1.855747
# Dyfed-Powys                          557   2.876897           1.834040
#
#                     num_pictures
# pfa16nm
# Metropolitan Police         1284
# Cumbria                     6869
# Lancashire                  3016
# Merseyside                   681
# Greater Manchester          1192
# Cheshire                    2296
# Northumbria                 5257
# Durham                      2367
# North Yorkshire             8073
# West Yorkshire              1921
# South Yorkshire             1431
# Humberside                  3532
# Cleveland                    299
# West Midlands               2968
# Staffordshire               2608
# West Mercia                 4838
# Warwickshire                1873
# Derbyshire                  2558
# Nottinghamshire             2087
# Lincolnshire                5732
# Leicestershire              2449
# Northamptonshire            2272
# Cambridgeshire              3209
# Norfolk                     5314
# Suffolk                     3796
# Bedfordshire                1187
# Hertfordshire               1648
# Essex                       3708
# Thames Valley               5558
# Hampshire                   4187
# Surrey                      1624
# Kent                        3851
# Sussex                      3694
# City of London                 4
# Devon and Cornwall         10616
# Avon and Somerset           4755
# Gloucestershire             2642
# Wiltshire                   3317
# Dorset                      2707
# North Wales                 6228
# Gwent                        591
# South Wales                 6290
# Dyfed-Powys                 6096
#
# [43 rows x 35 columns]

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

# set a variable that will call whatever column we want to visualise on the map
variable = 'Total recorded crime (excluding fraud)'

# set the range for the choropleth
vmin, vmax = int(max(merged[variable])), int(min(merged[variable]))

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 15))

# create map
merged.plot(column = variable, cmap = 'Blues', linewidth = 0.8, ax = ax, edgecolor = '0.8')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm._A = []

# add the colorbar to the figure
divider = make_axes_locatable(ax)
cax1 = divider.append_axes("right", size="5%", pad=0.05)
cbar = fig.colorbar(sm, cax = cax1)

# remove the axis
ax.axis('off')

# add a title
title = ax.set_title("Total Recorded Crime (excl. Fraud)", fontdict = {'fontsize': '25', 'fontweight' : '3'}, y = 50)

# create an annotation for the data source
ax.annotate('Source: London Datastore, 2014', xy = (0, 0), xycoords = 'axes fraction', 
            horizontalalignment = 'left', verticalalignment = 'top', fontsize = 12, color = '#555555')
# Out:
# Text(0, 0, 'Source: London Datastore, 2014')

# %%
vmax
# Out:
# 104112

# %%
# set a variable that will call whatever column we want to visualise on the map
variable = 'Avg_Rating'

# set the range for the choropleth
vmin, vmax = float(min(merged[variable])), float(max(merged[variable]))

# create figure and axes for Matplotlib
fig, ax = plt.subplots(1, figsize=(10, 15))

# create map
merged.plot(column = variable, cmap = 'viridis', linewidth = 0.8, ax = ax, edgecolor = '0.8')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=vmin, vmax=vmax))

# empty array for the data range
sm._A = []

# add the colorbar to the figure
divider = make_axes_locatable(ax)
cax1 = divider.append_axes("right", size="5%", pad=0.05)
cbar = fig.colorbar(sm, cax = cax1)

# remove the axis
ax.axis('off')

# add a title
title = ax.set_title("Average Rating", fontdict = {'fontsize': '25', 'fontweight' : '3'}, y = 50)

# create an annotation for the data source
ax.annotate('Source: London Datastore, 2014', xy = (0, 0), xycoords = 'axes fraction', 
            horizontalalignment = 'left', verticalalignment = 'top', fontsize = 12, color = '#555555')
# Out:
# Text(0, 0, 'Source: London Datastore, 2014')

# %%
vmax
# Out:
# 3
