# %% [markdown]
# # COGS 108 Final Project

# %% [markdown]
# # What the F*@%?!  A Look Into Swearing In Quentin Tarantino's Films

# %% [markdown]
# # Names
#
# - Christina Ho
# - Doljinsuren Zandanshatar
# - Janine Hou
# - Lawrence Ngo
# - Tatjana Tam

# %% [markdown]
# # Group Members IDs
#
# - A13542382
# - A13756923
# - A12998815
# - A13466300
# - A14064063

# %% [markdown]
# # Overview

# %% [markdown]
# Given that curse words are abundant in today’s film, television, and media landscape, we were curious to know as to whether or not profanity affects how well a film or show performs. Examining Quentin Tarantino’s films, well-known for their graphic violence and plethora of obscenities, we wondered if there is a relationship between the type of curse words used in his films (from 1992-2012 excluding Death Proof and The Hateful Eight) and the success of those films, using net gross, critical reviews, and awards as success metrics. We hypothesized that the films with the greatest number of sexual-related swear words will prove most successful by our rating system. Ultimately, we found that although there was some correlation between certain types of movies and individual metrics of success, like financial or critical, our sample size was not sufficient to make any firm conclusions.

# %% [markdown]
# # Research Question

# %% [markdown]
# For our data science project, we ask the question: is there a relationship between the type of curse words used in Quentin Tarantino’s movies (from 1992-2012, excluding Death Proof and The Hateful Eight) and the success of those movies? By grouping all the curse words into the four categories of swear words as defined by Professor Benjamin Bergen (religious concept, sexual activities, bodily functions and organs, and derogatory language for other social groups), we will analyze the category frequency per film with different metrics of success, using the movie’s net gross (in dollars), critical success (as a number out of ten), and Academy awards (in numbers).

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Our group bonded over our mutual love for film and pop culture, specifically the work of film auteurs like Quentin Tarantino and his unique style of filmmaking. Quentin Tarantino is a well-established, acclaimed, and successful director best known for his brilliantly shot films. Some well-known hallmarks of his films include non-linear storytelling, satire, and pop culture references. Tarantino is also known for employing numerous instances of stylized, graphic violence and an abundance of profanity throughout all of his films, all garnering “R” ratings. Looking over the different datasets, we were specifically drawn to the dataset documenting curse words across his films and decided to base our project off of it. We were ultimately interested in examining cultural shifts in the way that audiences have perceived--and become increasingly accepting of--profanity and more provocative content in films and pop culture, of which Tarantino’s films have become the unofficial agent for in Hollywood. Based on the common theme of swear words and given the success and popularity of his films, our team wondered if there was any correlation between the types of swear words spoken and each film’s success. Given the frequency and abundance of sexual content and sex-related swear words that are almost unavoidable in pop culture and media today (another prolific hallmark of Tarantino’s films as well), we predict that the films with the most sex-related swear words will be most successful overall. Whether proven or disproven, we hope our project can provide insight into the way our culture utilizes and views language, particularly of the profane nature, within the context of films.
#
# A previous study of Tarantino’s films found that the spread of profanity across his movies has not been consistent: over 75% of curse words were found in just three out of seven films studied, and over 90% of cursing in his movies was found in four out of the seven (2). Additionally, Tarantino seems to have a penchant for using various forms of the F-word, as its different forms make up a majority of curse words used in his films (2). The study also found that the types of swear words employed vary in proportion across movies depending on the type of film it was: for instance, while the F-word makes up a majority of curse words uttered in most of Tarantino’s films, Django Unchained was an exception in that it featured far more racial slurs compared to other types of swearing since it was a period piece about slavery (2). It was also noted that Tarantino’s use of R-rated swear words such as the F-word has decreased in recent years, possibly due to increasing mainstream popularity of his films (2). In addition, there is a difference in the type of swear words used and how often it is used between genders (1). This led us to explore whether swear words, and specifically what types, in Quentin Tarantino’s movies had an effect on how successfully the film performed.
#
# References (include links):
#   1) Cressman, Dale; Callister, Mark; Robinson, Tom; and Near, Chris, "Swearing In The Cinema: An analysis of profanity in US teenoriented movies, 1980-2006" (2009). All Faculty Publications. 137. https://scholarsarchive.byu.edu/cgi/viewcontent.cgi?article=1136&context=facpub
#
# 2) "Cursing in Quentin Tarantino's Films" (2013). RStudio.
# http://rstudio-pubs-static.s3.amazonaws.com/235553_58fbac0330f0432e9be75dca4df07b6b.html

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We expect that movies with the highest amount of swear words related to sexual activity will be most successful as a whole (equally weighing net gross, critical success, and awards) since these are very prevalent in mainstream society and used very frequently. However, it will be interesting to see how each category relates to different types of success; perhaps movies with high amounts of social swear words will amount to the greatest awards success due to the sensitivity of the subject.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: Tarantino
# - Link to the dataset: https://github.com/fivethirtyeight/data/tree/master/tarantino
# - Number of observations: 1895
# - Description: This dataset contains entries of all curse words, deaths, and their time location that have occurred in Quentin Tarantino's movies from 1992 - 2012 excluding Death Proof and The Hateful Eight.
#   <br>
# - Dataset Name: IMDB 5000
# - Link to the dataset: https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset
# - Number of observations: 5044
# - Description: This dataset contains entries of 5000+ movies and their related information found on IMDB such as, IMDB score, budget, gross, and etc.
#   <br>
# - Dataset Name: The Academy Awards 1927-2015
# - Link to the dataset: https://www.kaggle.com/theacademy/academy-awards
# - Number of observations: 9964
# - Description: This dataset contains entries of all Academy Award nominations, their category, and whether they won.
#
# We plan to use the Tarantino dataset to categorize the curse words used in his specified films and compare them to the different measures of success, such as, net gross and critical success through IMDB 5000's variables, gross, budget, and IMDB score, and Academy Awards success through the Academy Award 1927-2015' winning variable.

# %% [markdown]
# # Setup

# %%
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure libraries
# The seaborn library makes plots look nicer
sns.set()
sns.set_context('talk')

# Don't display too many rows/cols of DataFrames
pd.options.display.max_rows = 10
pd.options.display.max_columns = 10

# Round decimals when displaying DataFrames
pd.set_option('precision', 2)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Since our topic required three separate datasets that are independent from one another in terms of the data themselves, we chose to clean them up individually and use them instead of a collective one. For the first step in cleaning, we created multiple lists that contain all the base information that will be used to sort the information in the three datasets.
#
# The first list is the movie_list, which contains all the movies that we are looking into ordered by the year. The rest of the lists, labeled religion, sexual, bodily, and social, contain the curse words found in the swear words dataset which we organized into their corresponding lists. For example, “dick” would go into the bodily category list. Next, we went into cleaning the datasets.
#
# For the swear words dataset, we cleaned it by fixing any spelling errors of the movie titles and dropping unnecessary information, such as the time and type columns. We then searched through the curse words and assigned them a category based on which category list the curse word was in. We then organized the dataset in order of movie based on the movie_list.
#
# For the imdb dataset, we dropped all the unnecessary information by dropping all rows that didn’t have Quentin Tarantino as the director, and specifically the row for the movie “The Hateful Eight” because it is out of our time range of Quentin Tarantino’s movies we are analyzing. We then isolated the columns to be movie title, gross, budget, imdb score, and year. The use of the year column was to lastly organize the data into the same order as the movie_list.
#
# For the awards dataset, because there were issues with the film title and director name having either an extra space in the text and/or being flipped. Our first step was to get rid of the extra space by stripping the name and the movie title. We then isolated only the rows where the movie title or movie director name matched with the movies in movie_list. Afterwards, because of the issue where the movie title was flipped with the movie director name, we made a for loop that would check to see if the movie title was in the director name column, and then swapped them. The last step was to isolate the dataset even more into just the winner and movie name column.

# %%
#Movie and Category Lists
movie_list=['Reservoir Dogs', 'Pulp Fiction', 'Jackie Brown', 'Kill Bill: Vol. 1',
            'Kill Bill: Vol. 2', 'Inglourious Basterds', 'Django Unchained']
religion=['goddamned', 'bastards', 'bastard', 'goddamn', 'damn', 'damned', 'hell']
sexual=['fucked', 'fucking', 'fuck', 'fucks', 'fucker', 'fuckers', 'fuckup', 
        'motherfucker',  'cockblockery',  'fuckface', 'cocksucker', 'fuckhead', 
        'motherfuckers', 'motherfucking']
body=['dick', 'dicks', 'dumbass','jackass', 'shit', 'shitload', 'horseshit',  
      'shittiest', 'pussy', 'bullshit', 'shitless', 'shitting', 'horeshit', 'merde',
      'shithead',  'chickenshit', 'dickless', 'ass', 'asses', 'asshole', 'assholes',
      'asshead', 'shitty']
social=['slut', 'squaw', 'negro', 'negro ', 'jew', 'jew (verb)', 'n-word','n-word ',
        'gook', 'gooks', 'slope', 'bitch', 'bitches', 'faggot', 'jap', 'japs', 
        'wetback', 'cunt', 'cunts',]

#Swear Words Dataset Clean Up
words = pd.read_csv('tarantino.csv')
words['movie'] = words['movie'].replace('Inglorious Basterds', 'Inglourious Basterds')
words = words.drop(['minutes_in', 'type'], axis=1)
words = words.dropna()
words['category'] = np.nan
words.loc[words['word'].isin(religion), 'category'] = 'religion'
words.loc[words['word'].isin(sexual), 'category'] = 'sexual'
words.loc[words['word'].isin(body), 'category'] = 'bodily'
words.loc[words['word'].isin(social), 'category'] = 'social'
sorterIndex = dict(zip(movie_list,range(len(movie_list))))
words['movie_rank'] = words['movie'].map(sorterIndex)
words.sort_values(['movie_rank'], ascending = [True], inplace = True)
words = words.drop(['movie_rank'], axis=1)
print(words['category'].isnull().sum())
print(words)

#IMDB Dataset Clean Up
imdb = pd.read_csv('movie_metadata.csv')
imdb = imdb.drop(imdb[imdb.director_name != 'Quentin Tarantino'].index)
imdb = imdb.drop(706)
imdb = imdb.loc[:,['movie_title', 'gross', 'budget', 'imdb_score', 'title_year']]
imdb = imdb.sort_values(['title_year'])
print(imdb)

#Awards Dataset Clean Up
awards = pd.read_csv('database.csv')
awards['Film'] = awards['Film'].str.strip()
awards['Name'] = awards['Name'].str.strip()
awards = awards[awards['Film'].isin(movie_list) | awards['Name'].isin(movie_list)]
awards = awards.loc[:,['Winner', 'Film', 'Name']]
for i,award_row in awards.iterrows():
    for movie_index in range(0, len(movie_list)):
        name_storage = awards.loc[i,'Name']
        if name_storage == movie_list[movie_index]:
            film_storage = award_row["Name"]
            awards.loc[i,'Name'] = award_row['Film']
            awards.loc[i,'Film'] = film_storage
awards = awards.loc[:,['Winner', 'Film']]
print(awards)
# Out:
# 0
#                  movie          word  category
# 0       Reservoir Dogs          dick    bodily
# 288     Reservoir Dogs       goddamn  religion
# 287     Reservoir Dogs           ass    bodily
# 286     Reservoir Dogs  motherfucker    sexual
# 285     Reservoir Dogs       fucking    sexual
# ...                ...           ...       ...
# 1344  Django Unchained       n-word     social
# 1345  Django Unchained           ass    bodily
# 1346  Django Unchained          damn  religion
# 1335  Django Unchained       goddamn  religion
# 1332  Django Unchained       n-word     social
#
# [1704 rows x 3 columns]
#                 movie_title     gross    budget  imdb_score  title_year
# 4496        Reservoir Dogs   2.81e+06  1.20e+06         8.4      1992.0
# 3355          Pulp Fiction   1.08e+08  8.00e+06         8.9      1994.0
# 2930          Jackie Brown   3.96e+07  1.20e+07         7.5      1997.0
# 855      Kill Bill: Vol. 1   7.01e+07  3.00e+07         8.1      2003.0
# ...

# %% [markdown]
# # Data Analysis & Results

# %%
#Shape

print("Swear Words dataset shape: ", words.shape)
print("IMDB dataset shape: ", imdb.shape)
print("Academy Awards dataset shape: ", awards.shape)
# Out:
# Swear Words dataset shape:  (1704, 3)
# IMDB dataset shape:  (7, 5)
# Academy Awards dataset shape:  (21, 2)

# %%
#Missingness

null_words = words.isnull().any(axis=1)
print(null_words.sum())

null_imdb = imdb.isnull().any(axis=1)
print(null_imdb.sum())

null_awards = awards.isnull().any(axis=1)
print(null_awards.sum())
# Out:
# 0
# 0
# 17

# %% [markdown]
# For missingness in our datasets, as a result of our datacleaning, has no null values that are confounding or useless. The reason for the Awards dataset in having 17 null values, specifically in the "Winner" column, is because each null value represents a nomination for the film, while a 1 represents a win.

# %% [markdown]
# In order to see what categories of curse words were used most frequently in each movie, we made a function to sort each occurance of curse word to its corresponding category and add all occurrences. We did this for each movie and displayed the usage in bar graphs to visually represent category usage.

# %%
#Category Frequencies for Each Movie

def sum_religion(df):
    return (df.category == 'religion').sum()
def sum_body(df):
    return (df.category == 'bodily').sum()
def sum_sex(df):
    return (df.category == 'sexual').sum()
def sum_social(df):
    return (df.category == 'social').sum()

fig, ar = plt.subplots(2, 3, figsize=(20,10))

#'Reservoir Dogs'
dogs1_df = words.drop(['word'], axis=1)
dogs_df = dogs1_df[dogs1_df['movie'] == 'Reservoir Dogs']
dogs_body = sum_body(dogs_df)
dogs_religion = sum_religion(dogs_df)
dogs_sex = sum_sex(dogs_df)
dogs_social = sum_social(dogs_df)
count_7=[int(dogs_body), int(dogs_religion), int(dogs_sex), int(dogs_social)]
categories_7 = ['bodily', 'religion', 'sexual', 'social']
data_dogs = {'Reservoir Dogs':categories_7,'count_7':count_7}
df_dogs = pd.DataFrame(data_dogs)
dogs_bar = df_dogs.plot.bar(x='Reservoir Dogs', y='count_7', legend=False,
                            ax=ar[0][0])
ar[0][0].set_ylabel('Word Frequency')

#'Pulp Fiction'
pulp1_df = words.drop(['word'], axis=1)
pulp_df = pulp1_df[pulp1_df['movie'] == 'Pulp Fiction']
pulp_body = sum_body(pulp_df)
pulp_religion = sum_religion(pulp_df)
pulp_sex = sum_sex(pulp_df)
pulp_social = sum_social(pulp_df)
count_6=[int(pulp_body), int(pulp_religion), int(pulp_sex), int(pulp_social)]
categories_6 = ['bodily', 'religion', 'sexual', 'social']
data_pulp = {'Pulp Fiction':categories_6,'count_6':count_6}
df_pulp = pd.DataFrame(data_pulp)
pulp_bar = df_pulp.plot.bar(x='Pulp Fiction', y='count_6', legend=False, 
                            ax=ar[0][1])
ar[0][1].set_ylabel('Word Frequency')

#'Jackie Brown'
jackie1_df = words.drop(['word'], axis=1)
jackie_df = jackie1_df[jackie1_df['movie'] == 'Jackie Brown']
jackie_body = sum_body(jackie_df)
jackie_religion = sum_religion(jackie_df)
jackie_sex = sum_sex(jackie_df)
jackie_social = sum_social(jackie_df)
count_5=[int(jackie_body), int(jackie_religion), int(jackie_sex),
         int(jackie_social)]
categories_5 = ['bodily', 'religion', 'sexual', 'social']
data_jackie = {'Jackie Brown':categories_5,'count_5':count_5}
df_jackie = pd.DataFrame(data_jackie)
jackie_bar = df_jackie.plot.bar(x='Jackie Brown', y='count_5', legend=False,
                                ax=ar[0][2])
ar[0][2].set_ylabel('Word Frequency')

#'Kill Bill: Vol. 1'
kill1_df = words.drop(['word'], axis=1)
kill_df = kill1_df[kill1_df['movie'] == 'Kill Bill: Vol. 1']
kill_body = sum_body(kill_df)
kill_religion = sum_religion(kill_df)
kill_sex = sum_sex(kill_df)
kill_social = sum_social(kill_df)
count_3=[int(kill_body), int(kill_religion), int(kill_sex), int(kill_social)]
categories_3 = ['bodily', 'religion', 'sexual', 'social']
data_kill = {'Kill Bill: Vol. 1':categories_3,'count_3':count_3}
df_kill = pd.DataFrame(data_kill)
kill_bar = df_kill.plot.bar(x='Kill Bill: Vol. 1', y='count_3', legend=False,
                            ax=ar[1][0])
ar[1][0].set_ylabel('Word Frequency')

#'Kill Bill: Vol. 2'
kill21_df = words.drop(['word'], axis=1)
kill2_df = kill21_df[kill21_df['movie'] == 'Kill Bill: Vol. 2']
kill2_body = sum_body(kill2_df)
kill2_religion = sum_religion(kill2_df)
kill2_sex = sum_sex(kill2_df)
kill2_social = sum_social(kill2_df)
count_4=[int(kill2_body), int(kill2_religion), int(kill2_sex), int(kill2_social)]
categories_4 = ['bodily', 'religion', 'sexual', 'social']
data_kill2 = {'Kill Bill: Vol. 2':categories_4,'count_4':count_4}
df_kill2 = pd.DataFrame(data_kill2)
kill2_bar = df_kill2.plot.bar(x='Kill Bill: Vol. 2', y='count_4', legend=False, 
                              ax=ar[1][1])
ar[1][1].set_ylabel('Word Frequency')

#'Inglourious Basterds'
inglor1_df = words.drop(['word'], axis=1)
inglor_df = inglor1_df[inglor1_df['movie'] == 'Inglourious Basterds']
inglor_body = sum_body(inglor_df)
inglor_religion = sum_religion(inglor_df)
inglor_sex = sum_sex(inglor_df)
inglor_social = sum_social(inglor_df)
count_2=[int(inglor_body), int(inglor_religion), int(inglor_sex), int(inglor_social)]
categories_2 = ['bodily', 'religion', 'sexual', 'social']
data_inglor = {'Inglourious Basterds':categories_2,'count_2':count_2}
df_inglor = pd.DataFrame(data_inglor)
inglor_bar = df_inglor.plot.bar(x='Inglourious Basterds', y='count_2', legend=False,
                                ax=ar[1][2])
ar[1][2].set_ylabel('Word Frequency')

#'Django Unchained'
django1_df = words.drop(['word'], axis=1)
django_df = django1_df[django1_df['movie'] == 'Django Unchained']
django_body = sum_body(django_df)
django_religion = sum_religion(django_df)
django_sex = sum_sex(django_df)
django_social = sum_social(django_df)
count=[int(django_body), int(django_religion), int(django_sex), int(django_social)]
categories = ['bodily', 'religion', 'sexual', 'social']
data_django = {'Django Unchained':categories,'count':count}
df_django = pd.DataFrame(data_django)
django_bar = df_django.plot.bar(x='Django Unchained', y='count', legend=False, 
                                figsize =(5,3))
django_bar.set_ylabel('Word Frequency')

fig.tight_layout()

# %% [markdown]
# After looking at the trends in each movie, we found the averages of category use across all of the movies (as is shown by the Category Total bar graph). We then plotted the films against each other to show how they differed in terms of average category usage. By adding the average as a red line, we were able to see more clearly each movie's usage of categories in respect to each other and discover general trends of usage. Usage varied greatly per film,
# and the Kill Bill franchise as well as Inglourious Basterds had significantly lower usage than the other films.
# Pulp Fiction, Reservoir Dogs, and Jackie Brown had above average usage across all categories except for the derogatory terms against other social groups, in which Django Unchained had around three times as much usage than average.

# %%
#Category Comparison of All 7 Movies

#Category Sum of All 7 Movies
category_av = words.drop(['word'], axis=1)
category_av_body = sum_body(category_av)
category_av_religion = sum_religion(category_av)
category_av_sex = sum_sex(category_av)
category_av_social = sum_social(category_av)
count_av=[int(category_av_body), int(category_av_religion), int(category_av_sex), 
          int(category_av_social)]
categories_8 = ['bodily', 'religion', 'sexual', 'social']
data_category_av = {'Category Total':categories_8,'count_av':count_av}
df_category_av = pd.DataFrame(data_category_av)
category_av_bar = df_category_av.plot.bar(x='Category Total', y='count_av',
                                          legend=False)
category_av_bar.set_ylabel('Word Frequency')

fig, a = plt.subplots(2, 2, figsize=(18,20))

movies = ['Reservoir Dogs', 'Pulp Fiction', 'Jackie Brown', 'Kill Bill: Vol. 1', 
          'Kill Bill: Vol. 2', 'Inglourious Basterds', 'Django Unchained']

#Body Category
count_body=[dogs_body, pulp_body, jackie_body, kill_body, kill2_body, inglor_body,
            django_body]
data_category_body = {'Bodily':movies,'count_body':count_body}
df_body_av = pd.DataFrame(data_category_body)
body_av_bar = df_body_av.plot.bar(x='Bodily', y='count_body', legend=False,
                                  ax=a[0][0])
flat = np.array([category_av_body/7,category_av_body/7,category_av_body/7,
                 category_av_body/7,category_av_body/7,category_av_body/7,
                 category_av_body/7])
a[0][0].plot(df_body_av['Bodily'], flat, 'r--')
a[0][0].set_ylabel('Word Frequency')

#Religion Category
count_religion=[dogs_religion, pulp_religion, jackie_religion, kill_religion,
                kill2_religion, inglor_religion, django_religion]
data_category_religion = {'Religion':movies,'count_religion':count_religion}
df_religion_av = pd.DataFrame(data_category_religion)
religion_av_bar = df_religion_av.plot.bar(x='Religion', y='count_religion', 
                                          legend=False, ax=a[0][1])
flat2 = np.array([category_av_religion/7,category_av_religion/7,
                  category_av_religion/7,category_av_religion/7,
                  category_av_religion/7,category_av_religion/7,
                  category_av_religion/7])
a[0][1].plot(df_religion_av['Religion'], flat2, 'r--')
a[0][1].set_ylabel('Word Frequency')

#Sex Category
count_sex=[dogs_sex, pulp_sex, jackie_sex, kill_sex, kill2_sex, inglor_sex,
           django_sex]
data_category_sex = {'Sex':movies,'count_sex':count_sex}
df_sex_av = pd.DataFrame(data_category_sex)
sex_av_bar = df_sex_av.plot.bar(x='Sex', y='count_sex', legend=False, ax=a[1][0])
flat3 = np.array([category_av_sex/7,category_av_sex/7,category_av_sex/7,
                  category_av_sex/7,category_av_sex/7,category_av_sex/7,
                  category_av_sex/7])
a[1][0].plot(df_sex_av['Sex'], flat3, 'r--')
a[1][0].set_ylabel('Word Frequency')

#Social Category
count_social=[dogs_social, pulp_social, jackie_social, kill_social, kill2_social,
              inglor_social, django_social]
data_category_social = {'Social':movies,'count_social':count_social}
df_social_av = pd.DataFrame(data_category_social)
social_av_bar = df_social_av.plot.bar(x='Social', y='count_social', legend=False, 
                                      ax=a[1][1])
flat4 = np.array([category_av_social/7,category_av_social/7,category_av_social/7,
                  category_av_social/7,category_av_social/7,category_av_social/7,
                  category_av_social/7])
a[1][1].plot(df_social_av['Social'], flat4, 'r--')
a[1][1].set_ylabel('Word Frequency')

fig.tight_layout()

# %% [markdown]
# We then explored the degree of success each film received in: IMDB score as a number out of 10, number of awards won and nominated for, and gross in USD (1e8 for display purposes). The films were plotted against each other to establish an average (again displayed as a red dashed line), although an average line was not included on awards success since the awards and nominations varied greatly. Additionally, budget was added to the gross success bar graph to explore the relationship between budget and gross. An interesting thing to point out for the Financial Success graph is that as time progresses and more of his movies are made, the higher the budget he has. While gross and awards varied widely, the IMDB scores were all very close together in the range from 7 - 10. From the graphs we were able to find that Pulp Fiction, Django Unchained, and Inglourious Basterds had the most success.

# %%
#Success Comparisons of All 7 Movies

fig, arr = plt.subplots(1, 3, figsize=(20,5))

#Net Gross
imdb_gross = pd.DataFrame(imdb) #to get right title on graph
imdb_gross['Financial Success'] = imdb['movie_title']
imdb_gross.plot.bar(x='Financial Success', y=['gross','budget'], ax=arr[0])
gross_mean = imdb['gross'].mean()
budget_mean = imdb['budget'].mean()
flat5 = np.array([gross_mean,gross_mean,gross_mean,gross_mean,gross_mean,
                  gross_mean,gross_mean])
arr[0].plot(imdb['movie_title'], flat5, 'r--', color='blue')
flat6 = np.array([budget_mean,budget_mean,budget_mean,budget_mean,
                  budget_mean,budget_mean,budget_mean])
arr[0].plot(imdb['movie_title'], flat6, 'r--', color='orange')
arr[0].set_ylabel('USD in $1e8')

#IMDB score
imdb_success = pd.DataFrame(imdb) #to get right title on graph
imdb_success['Ratings Success'] = imdb['movie_title'] #to get right title on graph
imdb_success.plot.bar(x='Ratings Success', y='imdb_score', ax=arr[1], legend=False)
score_mean = imdb['imdb_score'].mean()
flat7 = np.array([score_mean,score_mean,score_mean,score_mean,score_mean,score_mean,
                  score_mean])
arr[1].plot(imdb['movie_title'], flat7, 'r--', color='red')
arr[1].set_ylabel('IMDB Score out of 10')
arr[1].set_ylim(7,9)

#Awards
award_df = pd.DataFrame(movie_list, columns=['Awards Success'])
award_df['total'] = ''
award_df['won'] = ''
award_df['nominated'] = ''
for i in movie_list:
    allAwards = (awards['Film'] == i).sum()
    won = ((awards['Film'] == i) & (awards['Winner'] == 1.0)).sum()
    award_df.loc[(award_df['Awards Success'] == i), 'total'] =  allAwards
    award_df.loc[(award_df['Awards Success'] == i), 'won'] =  won
    award_df.loc[(award_df['Awards Success'] == i), 'nominated'] = (allAwards - won)
award_df.plot.bar('Awards Success',['won','nominated'],stacked=True, ax=arr[2]);
arr[2].set_ylabel('Number of Awards')
# Out:
# Text(0, 0.5, 'Number of Awards')

# %% [markdown]
# Our next step was to compare the usage of curse word categories directly to our measures of success. To do so, we analyzed each movie's category use in relation to all the curse words used in the movie, establishing a percentage per category. We then visually analyzed the relationship between percentage per category and types of success through scatterplots with best fit lines to show the trend in the data. Each type of success was compared with
# each category and the relationship between category and success can be described by the slope of the best fit line, as well as the correlation tables which showed the correlation between each variable. The most pertinent data for our analysis resides in the first row of the first table (total is awards) and the gross and imdb_score rows of the second table.

# %%
#Sum Percentages for Each Category for Each Movie

#'Resevoir Dogs'
r_sum=int(dogs_body)+ int(dogs_religion)+ int(dogs_sex)+ int(dogs_social)
r_body = int(dogs_body)/int(r_sum)
r_religion = int(dogs_religion)/int(r_sum)
r_sex = int(dogs_sex)/int(r_sum)
r_social = int(dogs_social)/int(r_sum)

#'Pulp Fiction'
p_sum=int(pulp_body)+ int(pulp_religion)+ int(pulp_sex)+ int(pulp_social)
p_body = int(pulp_body)/int(p_sum)
p_religion = int(pulp_religion)/int(p_sum)
p_sex = int(pulp_sex)/int(p_sum)
p_social = int(pulp_social)/int(p_sum)

#'Jackie Brown'
j_sum=int(jackie_body)+ int(jackie_religion)+ int(jackie_sex)+ int(jackie_social)
j_body = int(jackie_body)/int(j_sum)
j_religion = int(jackie_religion)/int(j_sum)
j_sex = int(kill2_sex)/int(j_sum)
j_social = int(kill2_body)/int(j_sum)

#'Kill Bill Volume I'
k_sum=int(kill_body)+ int(kill_religion)+ int(kill_sex)+ int(kill_social)
k_body = int(kill_body)/int(k_sum)
k_religion = int(kill_religion)/int(k_sum)
k_sex = int(kill_sex)/int(k_sum)
k_social = int(kill_social)/int(k_sum)

#'Kill Bill Volume II'
k2_sum=int(kill2_body)+ int(kill2_religion)+ int(kill2_sex)+ int(kill2_social)
k2_body = int(kill2_body)/int(k2_sum)
k2_religion = int(kill2_religion)/int(k2_sum)
k2_sex = int(kill2_sex)/int(k2_sum)
k2_social = int(kill2_social)/int(k2_sum)

#'Inglorious Basterds'
i_sum= int(inglor_body)+ int(inglor_religion)+ int(inglor_sex)+ int(inglor_social)
i_body = int(inglor_body)/int(i_sum)
i_religion = int(inglor_religion)/int(i_sum)
i_sex = int(inglor_sex)/int(i_sum)
i_social = int(inglor_social)/int(i_sum)

#'Django Unchained'
d_sum =int(django_body) + int(django_religion)+ int(django_sex)+ int(django_social)
d_body = int(django_body)/int(d_sum)
d_religion = int(django_religion)/int(d_sum)
d_sex = int(django_sex)/int(d_sum)
d_social = int(django_social)/int(d_sum)

# %%
# Add Percentages to Dataframes

x_body=[r_body, p_body, j_body, k_body, k2_body, i_body, d_body]
x_religion =[r_religion, p_religion, j_religion, k_religion, k2_religion, i_religion,
             d_religion]
x_sex = [r_sex, p_sex, j_sex, k_sex, k2_sex, i_sex, d_sex]
x_social =[r_social, p_social, j_social, k_social, k2_social, i_social, d_social]
award_df['body'] = x_body
award_df['religion'] = x_religion
award_df['sex'] = x_sex
award_df['social'] = x_social
award_df['total'] = award_df['total'].astype(float)

imdb['body'] = x_body
imdb['religion'] = x_religion
imdb['sex'] = x_sex
imdb['social'] = x_social

# %%
#Scatterplot for Category vs Awards

fig, arr = plt.subplots(2,2, figsize=(15,10))
arr[0][0].scatter(x_body, award_df['total'])
a1, b1 = np.polyfit(x_body, award_df['total'], 1)
xs = np.linspace(0.15, 0.4, 100)
ys = a1*xs +b1
arr[0][0].plot(xs, ys, color='r', label=a1)
arr[0][0].title.set_text("Body Category vs Awards")
arr[0][0].set_ylabel('Number of Awards')
arr[0][0].set_xlabel('Percent of Category Used in Film')

arr[0][1].scatter(x_religion, award_df['total'])
a2, b2 = np.polyfit(x_religion, award_df['total'], 1)
xs = np.linspace(0.0, 0.4, 100)
ys = a2*xs +b2
arr[0][1].plot(xs, ys, color='r')
arr[0][1].title.set_text("Religion Category vs Awards")
arr[0][1].set_ylabel('Number of Awards')
arr[0][1].set_xlabel('Percent of Category Used in Film')

arr[1][0].scatter(x_sex, award_df['total'])
a3, b3 = np.polyfit(x_sex, award_df['total'], 1)
xs = np.linspace(0.0, 0.8, 100)
ys = a3*xs +b3
arr[1][0].plot(xs, ys, color='r')
arr[1][0].title.set_text("Sex Category vs Awards")
arr[1][0].set_ylabel('Number of Awards')
arr[1][0].set_xlabel('Percent of Category Used in Film')

arr[1][1].scatter(x_social, award_df['total'])
a4, b4 = np.polyfit(x_social, award_df['total'], 1)
xs = np.linspace(0.0, 0.55, 100)
ys = a4*xs +b4
arr[1][1].plot(xs, ys, color='r')
arr[1][1].title.set_text("Social Category vs Awards")
arr[1][1].set_ylabel('Number of Awards')
arr[1][1].set_xlabel('Percent of Category Used in Film')

fig.tight_layout()

# %% [markdown]
# Awards Scatterplots:
# - Body Category vs Awards has a slope of -33.66, indicating a negative relationship between awards and usage of body-related curse words. While the data points are spread out, they are all generally in the same direction of spread. The correlation is -0.58, which is the highest correlation between category and awards.
# <br>
# - Religion Category vs Awards has a slope of 12.46, indicating a positive relationship between the use of body-related curse words and winning/nomination of awards. However, the data is very spread out and three movies were not nominated, which created a line of data points at zero despite differing levels of religion curse usage. The correlation is 0.28, a relatively low indicator of strength.
# <br>
# - Sex Category vs Awards has a slope of 0.83, inidcating a weakly positive relationship between use of sex-related curse words and awards. The spread of data shows that there is no real correlation as can be seen by the correlation score of 0.05, the weakest in all of our analysis.
# <br>
# - Social Category vs Awards has a slope of 6.36, indicating a positive relationship between use of social-related curse words and awards. Many of the data points are clustered at 0 awards and no real indication of a relationship. The correlation is 0.27, very similar to the religion category.

# %%
#Scatterplot for Category vs Gross

fig, arr = plt.subplots(2,2, figsize=(15,10))
arr[0][0].scatter(imdb['body'], imdb['gross'])
c1, d1 = np.polyfit(imdb['body'], imdb['gross'], 1)
xs = np.linspace(0.15, 0.4, 100)
ys = c1*xs +d1
arr[0][0].plot(xs, ys, color='r')
arr[0][0].title.set_text("Body Category vs Gross")
arr[0][0].set_ylabel('USD in $1e8')
arr[0][0].set_xlabel('Percent of Category Used in Film')

arr[0][1].scatter(imdb['religion'], imdb['gross'])
c2, d2 = np.polyfit(imdb['religion'], imdb['gross'], 1)
xs = np.linspace(0.0, 0.4, 100)
ys = c2*xs +d2
arr[0][1].plot(xs, ys, color='r')
arr[0][1].title.set_text("Religion Category vs Gross")
arr[0][1].set_ylabel('USD in $1e8')
arr[0][1].set_xlabel('Percent of Category Used in Film')

arr[1][0].scatter(imdb['sex'], imdb['gross'])
c3, d3 = np.polyfit(imdb['sex'], imdb['gross'], 1)
xs = np.linspace(0.0, 0.4, 100)
ys = c3*xs +d3
arr[1][0].plot(xs, ys, color='r')
arr[1][0].title.set_text("Sex Category vs Gross")
arr[1][0].set_ylabel('USD in $1e8')
arr[1][0].set_xlabel('Percent of Category Used in Film')

arr[1][1].scatter(imdb['social'], imdb['gross'])
c4, d4 = np.polyfit(imdb['social'], imdb['gross'], 1)
xs = np.linspace(0.0, 0.4, 100)
ys = c4*xs +d4
arr[1][1].plot(xs, ys, color='r')
arr[1][1].title.set_text("Social Category vs Gross")
arr[1][1].set_ylabel('USD in $1e8')
arr[1][1].set_xlabel('Percent of Category Used in Film')

fig.tight_layout()
plt.show()

# %% [markdown]
# Financial Scatterplots:
# - Body Category vs Gross has a slope of -497929926.33, indicating a strong negative relationship between use of body-related curse words and gross. The data points are close to the line of best fit with a single outlier of Reservoir Dogs dragging the correlation to -0.58.
# <br>
# - Religion Category vs Gross has a slope of 370038439.957, indicating a positive relationship between use of religious curse words and gross. A majority of the data points are in a linear formation, however, two data points are higher than the rest, making the correlation average 0.54.
# <br>
# - Sex Category vs Gross has a slope of -87646635.352, indicating a weakly negative relationship between use of sex-related curse words and gross. The data is very spread out and has a low correlation of -0.35.
# <br>
# - Social Category vs Gross has a slope of 274261758.303, indicating a relatively strong positive relationship between social-related curse words and gross. The data is all clustered at less than 20% except for an outlier (Django Unchained) which is over 40%. However, the outlier keeps with the positive trend. This scatterplot had the highest correlation at 0.78.

# %%
#Scatterplot for Category vs IMDB Score

fig, arr = plt.subplots(2,2, figsize=(15,10))
arr[0][0].scatter(imdb['body'], imdb['imdb_score'])
e1, f1 = np.polyfit(imdb['body'], imdb['imdb_score'], 1)
xs = np.linspace(0.15, 0.4, 100)
ys = e1*xs +f1
arr[0][0].plot(xs, ys, color='r')
arr[0][0].title.set_text("Body Category vs Imdb_Score")
arr[0][0].set_ylabel('IMDB Score out of 10')
arr[0][0].set_xlabel('Percent of Category Used in Film')

arr[0][1].scatter(imdb['religion'], imdb['imdb_score'])
e2, f2 = np.polyfit(imdb['religion'], imdb['imdb_score'], 1)
xs = np.linspace(0.0, 0.4, 100)
ys = e2*xs +f2
arr[0][1].plot(xs, ys, color='r')
arr[0][1].title.set_text("Religion Category vs Imdb_Score")
arr[0][1].set_ylabel('IMDB Score out of 10')
arr[0][1].set_xlabel('Percent of Category Used in Film')

arr[1][0].scatter(imdb['sex'], imdb['imdb_score'])
e3, f3 = np.polyfit(imdb['sex'], imdb['imdb_score'], 1)
xs = np.linspace(0.0, 0.7, 100)
ys = e3*xs +f3
arr[1][0].plot(xs, ys, color='r')
arr[1][0].title.set_text("Sex Category vs Imdb_Score")
arr[1][0].set_ylabel('IMDB Score out of 10')
arr[1][0].set_xlabel('Percent of Category Used in Film')

arr[1][1].scatter(imdb['social'], imdb['imdb_score'])
e4, f4 = np.polyfit(imdb['social'], imdb['imdb_score'], 1)
xs = np.linspace(0.0, 0.6, 100)
ys = e4*xs +f4
arr[1][1].plot(xs, ys, color='r')
arr[1][1].title.set_text("Social Category vs Imdb_Score")
arr[1][1].set_ylabel('IMDB Score out of 10')
arr[1][1].set_xlabel('Percent of Category Used in Film')

fig.tight_layout()
plt.show()

# %% [markdown]
# Rating Scatterplots:
# - Body Category vs Imdb_Score has a slope of -5.01, indicating a strong negative correlation between use of body-related curse words and ratings. The correlation is -0.71 and most of the data points are close to the line of best fit.
# <br>
# - Religion Category vs Imdb_Score has a slope of -0.83, indicating a relatively weak negative correlation between use of religious curse words and ratings. The correlation is -0.15 and the weak correlation can be seen by how spread out the data points are.
# <br>
# - Sex Category vs Imdb_Score has a slope of 1.28, indicating a positive correlation between sex-related curse words and ratings. The correlation is relatively strong at 0.62 with all of the data points in the same trending direction, however some of the data points are far from the line.
# <br>
# - Social Category vs Imdb_Score has a slope of 0.68, indicating a relatively weak correlation between social-related curse words and ratings. The correlation is 0.24 and there is no real relationship visible.

# %%
#Correlation of Variables
display(award_df.corr())
display(imdb.corr())
# Out:
#           total  body  religion   sex  social
# total      1.00 -0.58      0.28  0.05    0.27
# body      -0.58  1.00     -0.34 -0.21   -0.57
# religion   0.28 -0.34      1.00 -0.44    0.47
# sex        0.05 -0.21     -0.44  1.00   -0.51
# social     0.27 -0.57      0.47 -0.51    1.00
#             gross  budget  imdb_score  title_year  body  religion   sex  \
# gross        1.00    0.83        0.46        0.76 -0.58      0.54 -0.35
# budget       0.83    1.00        0.15        0.95 -0.63      0.73 -0.50
# imdb_score   0.46    0.15        1.00       -0.04 -0.71     -0.15  0.62
# title_year   0.76    0.95       -0.04        1.00 -0.41      0.84 -0.58
# body        -0.58   -0.63       -0.71       -0.41  1.00     -0.34 -0.21
# religion     0.54    0.73       -0.15        0.84 -0.34      1.00 -0.44
# sex         -0.35   -0.50        0.62       -0.58 -0.21     -0.44  1.00
# social       0.78    0.87        0.24        0.80 -0.57      0.47 -0.51
#
#             social
# ...

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# As big data plays an increasingly crucial role in our everyday lives, ethical and privacy considerations regarding dataset access, biases, misuse, and personal information breaches become more necessary. Given the serious consequences of such violations, we proceeded with our project with ethical and privacy considerations every step of the way. We must note the mature content of our project and obscenities found in the datasets as a result of the vulgar nature of Quentin Tarantino’s films, which include instances of sexism, racism, and graphic violence. The datasets we used are all open, authorized for public use, and accessible by everyone as public resources. Our first dataset, containing entries of all curse words, deaths, and timestamps of when they appear in Tarantino's movies--with the exception of Death Proof, was published by a user on GitHub and subsequently featured on “FiveThirtyEight”, an open-access, dataset-publishing website. Our second and third datasets are from the website “Kaggle”, a popular online public community for finding and publishing open datasets. We did not have to deal with any privacy or terms of use concerns as they do not infringe on any individual’s privacy since all information collected is public and specifically about films. An issue we faced regarding potential biases was how we chose what data to collect and display, as some of the datasets we used had missing information, and we subsequently had to drop two films. In this case, we had to exclude the films Death Proof and The Hateful Eight, as the “FiveThirtyEight” dataset did not include these films. As a result, an ethical consideration is that there will be bias in the data collection since it does not contain all of Quentin Tarantino’s films and that the analysis may not be equitable.
#
# There is also potential bias and error in the collection of data for the datasets themselves: the creator of the “FiveThirtyEight” dataset notes that, since he personally went through each movie and manually kept track of the curse word count, “it [was] occasionally difficult to make out the profane language precisely” but that he did his “best to count all the curses.” Additionally, an ethical consideration that may result in some bias is that as we are comparing the categories of swear words to the success of Tarantino’s films, we will have to define what we consider to be “successful” and that definition may conflict with what others consider to be successful. Another potential area of subjectivity is the way in which we defined and categorized the swear words. We used Cognitive Science professor Benjamin Bergen’s book What the F: What Swearing Reveals About Our Language, Our Brains, and Ourselves (2016) to guide our categorization, but it is still subjective categorization and anyone could make an argument against our swear word placement in a category. For safe measure, we asked Benjamin Bergen himself where “cunt” should be since it is technically a body organ and is derogatory towards women, and he replied that “cunt” should be in the derogatory section. Our analysis also runs the risk of being used by others to either support or discourage profanity in films and may be used as an argument for films to have more or fewer swear words. We conducted this analysis with no agenda and with a clear reminder that correlation does not equal causation.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# So, is there a relationship between the type of curse words used in Quentin Tarantino’s movies (excluding Death Proof and The Hateful Eight) and the success of those movies? We do note that our research was centered around only seven movies and excludes two important films, so our data is not large enough to reject or support a hypothesis. We also must take note of the fact that the year in which the film was released and its budget could have also affected the success of the movie. From our groundwork and analysis, we were not able to find enough significant evidence to confidently say there is a correlation. We reject our hypothesis that Quentin Tarantino’s movies with the highest amount of swear words related to sexual activity may be correlated with more success than other Tarantino films.
#
# We judged success through comparing domestic net gross, ratings, and awards to the average of each. Unfortunately, we found no correlation between award success and sexual swearing in Tarantino’s films. Jackie Brown, for example, had one of the higher counts of sexual terms but was not correlated with any form of success. We did, however, demonstrate evidence that there are distinct areas where different movies did have significant correlation, such as with ratings success and financial success. According to our table, the correlation between net gross success and sex-related swears is 0.78 (strong). From analysing graph data, the three movies with the highest ratings are Pulp Fiction, Django Unchained, and Reservoir Dogs, each of which had one of the highest counts of swears in one category or more. Pulp Fiction had the highest number of sexual terms (>250) and was more successful than other films, with seven Academy Award® nominations and a domestic net gross of ~107M, which is more than the average Tarantino film. Something notable to consider is that we found one movie that strongly corresponds with our unofficial hypothesis that perhaps movies with high counts of derogatory language against social groups would correlate with more success. Django Unchained had the largest number of derogatory (>125) and religious curses (>50), and a net worth of 163M$. Since this is far above the average net worth among Tarantino’s films, it could be considered successful. Also worth mentioning is that we found a scatterplot that demonstrated a strong correlational relationship between bodily function/organ swear words and IMDb scores.
#
# All in all, we found minimal evidence that may support our hypothesis with movies such as Pulp Fiction and Django Unchained, but our sample size is too small to draw any conclusions with confidence and our evidence is not strong enough. Our work may impact how people view swearing in Tarantino’s films and might be used to further an argument for or against swearing, though we doubt people would trust the legitimacy of our research given the limitations we have. The best step forward would be to find a way to include Death Proof and The Hateful Eight into our dataset and observe if it rejects our hypothesis. Furthermore, we could open our research to analysing swear words in popular movies from the past decade in the U.S. and test our hypothesis once again.
