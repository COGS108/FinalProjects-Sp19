# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import re

# %%
def manualchecking(df):
    if os.path.isfile("event.txt"):
        os.remove("event.txt")
    if os.path.isfile("disposition.txt"):
        os.remove("disposition.txt")
    if os.path.isfile("location.txt"):
        os.remove("location.txt")
    with open("event.txt", "w") as txt:
        for i, n in zip(df.groupby("Event").count().index, df.groupby("Event").count()["Location"]):
            txt.write(f"'{i}',\n")
            #txt.write(f"{i}~{n}\n")
    with open("disposition.txt", "w") as txt:
        for i, n in zip(df.groupby("Disposition:").count().index, df.groupby("Disposition:").count()["Event"]):
            txt.write(f"'{i}',\n")
            #txt.write(f"{i}~{n}\n")
    with open("location.txt", "w") as txt:
        for i, n in zip(df.groupby("Location").count().index, df.groupby("Location").count()["Event"]):
            txt.write(f"'{i}',\n")
            #txt.write(f"{i}~{n}\n")
            
def printTxt(filename):
    with open(filename, "r") as f:
        print(f.read())
        
def searchAndReplace(find, replace, column, df):
    df[column] = df[column].apply(lambda string: re.sub(find, replace, string) if pd.notnull(string) else string)

# %%
data = pd.read_csv("aggregate.csv")

# %%
searchAndReplace(r"/", "-", "Location", data)
searchAndReplace(r"-", " - ", "Location", data)
searchAndReplace(r":", " -", "Location", data)
searchAndReplace(r"  ", " ", "Location", data)
searchAndReplace(r"√©", "e", "Location", data)
searchAndReplace(r"é", "e", "Location", data)

# %%
searchAndReplace(r"bldg", "building", "Location", data)

# %%
cait =[
    "cal it 2",
    'cal it2',
    'calit 2',
    'calit2',
    'california institute for telecommunication and information technology',
    'ca insitute for telecommunication',
    'ca institute',
    'ca institute for telecomm',
    'ca institute for telecomm & information technology',
    'ca institute for telecomm and information technology',
    'ca institute for telecomm in',
    'ca institute for telecommunication',
    'ca institute for telecommunications',
    'ca institute for telecommunications and information technology',
]
for t in cait:
    searchAndReplace(r"^{}$".format(t), "california institute for telecommunications and information technology", "Location", data)
searchAndReplace(r"cal it", "california institute for telecommunications and information technology", "Location", data)

# %%
searchAndReplace(r"1 miramar", "one miramar", "Location", data)
searchAndReplace(r"1 miramr", "one miramar", "Location", data)
searchAndReplace(r"bick", "bike", "Location", data)

# %%
searchAndReplace(r"bike stand", "bike rack", "Location", data)
searchAndReplace(r"(?<![a-z])ave(?!nue)", "avenue", "Location", data)
searchAndReplace(r" dr(?![a-z])", " drive", "Location", data)
searchAndReplace(r" ln", " lane", "Location", data)
searchAndReplace(r" rd", " road", "Location", data)
searchAndReplace(r" blvd", " boulevard", "Location", data)
searchAndReplace(r"n\.", "north", "Location", data)
searchAndReplace(r"w\.", "west", "Location", data)
searchAndReplace(r"w arbor drive", "west arbor drive", "Location", data)
searchAndReplace(r"st\.", "saint", "Location", data)
searchAndReplace(r"ct\.", "court", "Location", data)
searchAndReplace(r" wy", " way", "Location", data)
searchAndReplace(r"\.", "", "Location", data)
searchAndReplace(r"ct\.", "court", "Location", data)
searchAndReplace(r"apts", "apartments", "Location", data)
searchAndReplace(r"pkwy", "parkway", "Location", data)
searchAndReplace(r"(?<=[^a-z])ct(?![a-z])", "court", "Location", data)
searchAndReplace(r"ovt", "oceanview terrace", "Location", data)
searchAndReplace(r"'", "", "Location", data)
searchAndReplace(r", california", "", "Location", data)
searchAndReplace(r", ca", "", "Location", data)
searchAndReplace(r"i - 5", "i-5", "Location", data)
searchAndReplace(r"i5", "i-5", "Location", data)
searchAndReplace(r"interstate ", "i-", "Location", data)
searchAndReplace(r" st ", " street ", "Location", data)
searchAndReplace(r" st$", " street", "Location", data)
searchAndReplace(r"i - 8", "i-8", "Location", data)
searchAndReplace(r"i - 9", "i-9", "Location", data)
searchAndReplace(r"i - 6", "i-6", "Location", data)
searchAndReplace(r"i - h", "i-h", "Location", data)
searchAndReplace(r"i - w", "i-w", "Location", data)

# %%
searchAndReplace(r"h&ss", "humanities and social sciences building", "Location", data)
searchAndReplace(r"apm", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"ap&m", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"ap& m", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"building building", "building", "Location", data)
searchAndReplace(r"^applies physics and math$", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"^applied physics and math$", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"^applied mathematics and science building$", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"^applied physics$", "applied physics and mathematics building", "Location", data)
searchAndReplace(r"^applied physics and mathematics$", "applied physics and mathematics building", "Location", data)

# %%
searchAndReplace(r"warrant", "warren", "Location", data)
searchAndReplace(r", san diego, ca", "", "Location", data)
searchAndReplace(r", san diego ca", "", "Location", data)
searchAndReplace(r", san diego", "", "Location", data)
searchAndReplace(r", la jolla", "", "Location", data)
searchAndReplace(r"loading(?! dock)", "loading dock", "Location", data)
searchAndReplace(r"(?<=[a-z]) loading dock", " - loading dock", "Location", data)
searchAndReplace(r"(?<=[a-z]) bike rack", " - bike rack", "Location", data)
searchAndReplace(r"(?<=[a-z]) commuter lounge", " - commuter lounge", "Location", data)
searchAndReplace(r"(?<=[a-z]) laundry room", " - laundry room", "Location", data)
searchAndReplace(r"(?<=[a-z]) leasing office", " - leasing office", "Location", data)
searchAndReplace(r"bike racks", "bike rack", "Location", data)

# %%
searchAndReplace(r"africal", "africa", "Location", data)
searchAndReplace(r"^undergrad admissions$", "ucsd undergrad admissions", "Location", data)
searchAndReplace(r"(?<!birch )admissions office", "ucsd undergrad admissions", "Location", data)
searchAndReplace(r"admission office", "ucsd undergrad admissions", "Location", data)
searchAndReplace(r"russel(?!l)", "russell", "Location", data)
searchAndReplace(r" res ", " residential ", "Location", data)
searchAndReplace(r"halls", "hall", "Location", data)
searchAndReplace(r"residence", "residential", "Location", data)
searchAndReplace(r" resident ", " residential ", "Location", data)
searchAndReplace(r"genessee", "genesee", "Location", data)
searchAndReplace(r"genesee(?! avenue)", "genesee avenue", "Location", data)
searchAndReplace(r"pepper canyon(?! hall)", "pepper canyon hall", "Location", data)
searchAndReplace(r"north torrey pines(?! road)", "north torrey pines road", "Location", data)
searchAndReplace(r"peets(?! coffee)", "peets coffee", "Location", data)
searchAndReplace(r"geisel(?! library)", "geisel library", "Location", data)
searchAndReplace(r"insritute", "institute", "Location", data)
searchAndReplace(r"sal institute", "salk institute", "Location", data)
searchAndReplace(r"galbraith hal$", "galbraith hall", "Location", data)
searchAndReplace(r"galbraith(?! hall)", "galbraith hall", "Location", data)
searchAndReplace(r"expedition(?! way)", "expedition way", "Location", data)
searchAndReplace(r"mt soledad", "mount soledad", "Location", data)
searchAndReplace(r"conyonview", "canyon", "Location", data)
searchAndReplace(r"bus bench", "bus stop", "Location", data)
searchAndReplace(r"hopking", "hopkins", "Location", data)
searchAndReplace(r"voight", "voigt", "Location", data)
searchAndReplace(r"vogt", "voigt", "Location", data)
searchAndReplace(r"warren hall", "warren lecture hall", "Location", data)
searchAndReplace(r"asian hall", "asia hall", "Location", data)
searchAndReplace(r"bates -", "bates hall -", "Location", data)
searchAndReplace(r"bathe", "bates", "Location", data)
searchAndReplace(r"&", "and", "Location", data)
searchAndReplace(r"apartment(?!s)", "apartments", "Location", data)
searchAndReplace(r"altman ctri building", "altman clinical and translational research institute", "Location", data)
searchAndReplace(r"ctri building", "altman clinical and translational research institute", "Location", data)
searchAndReplace(r"cse", "computer science and engineering", "Location", data)
searchAndReplace(r"cpmc", "conrad prebys music center", "Location", data)
searchAndReplace(r"^conrad$", "conrad prebys music center", "Location", data)
searchAndReplace(r"^prebys music building$", "conrad prebys music center", "Location", data)
searchAndReplace(r"^prebys music center$", "conrad prebys music center", "Location", data)
searchAndReplace(r"^prebys music hall$", "conrad prebys music center", "Location", data)
searchAndReplace(r"wlh", "warren lecture hall", "Location", data)
searchAndReplace(r"mathews", "matthews", "Location", data)
searchAndReplace(r"engineers lane", "engineer lane", "Location", data)
searchAndReplace(r"messa", "mesa", "Location", data)
searchAndReplace(r"riata", "rita", "Location", data)
searchAndReplace(r"plazae", "plaza", "Location", data)
searchAndReplace(r"gymnasium", "gym", "Location", data)
searchAndReplace(r"round table(?! pizza)", "round table pizza", "Location", data)
searchAndReplace(r"nobel(?! (apartments|drive))", "drive", "Location", data)
searchAndReplace(r"cmmw", "cellular and molecular medicine west", "Location", data)
searchAndReplace(r"cmme", "cellular and molecular medicine east", "Location", data)
searchAndReplace(r"irps", "school of international relations and pacific studies", "Location", data)
searchAndReplace(r"labs", "laboratory", "Location", data)
searchAndReplace(r"lab(?![a-z])", "laboratory", "Location", data)
searchAndReplace(r"igpp", "institute of geophysics and planetary physics", "Location", data)
searchAndReplace(r"ihouse", "international house", "Location", data)
searchAndReplace(r"i-house", "international house", "Location", data)
searchAndReplace(r"jay", "j", "Location", data)
searchAndReplace(r"john j hopkins(?! drive)", "john j hopkins drive", "Location", data)
searchAndReplace(r"kennel -", "kennel way -", "Location", data)
searchAndReplace(r"de sol office", "la jolla del sol apartments - leasing office", "Location", data)
searchAndReplace(r"la jolla del sole apartments", "la jolla del sol apartments", "Location", data)
searchAndReplace(r"la jolla del sol leasing office", "la jolla del sol apartments - leasing office", "Location", data)
searchAndReplace(r"(?<!la jolla )del sol", "la jolla del sol", "Location", data)
searchAndReplace(r"la jolla del sol(?! apar)", "la jolla del sol apartments", "Location", data)
searchAndReplace(r"del sol", "la jolla del sol", "Location", data)
searchAndReplace(r"dougals", "douglas", "Location", data)
searchAndReplace(r"douglass", "douglas", "Location", data)
searchAndReplace(r"douglas apartments", "douglas hall", "Location", data)
searchAndReplace(r"earth hall apartments", "earth hall", "Location", data)
searchAndReplace(r"decora", "decoro", "Location", data)
searchAndReplace(r"decors", "decoro", "Location", data)
searchAndReplace(r"decoro(?! street)", "decoro street", "Location", data)
searchAndReplace(r"galabraith", "galbraith", "Location", data)
searchAndReplace(r"east gate mall", "eastgate mall", "Location", data)
searchAndReplace(r"genesee avenue av", "genesee avenue", "Location", data)
searchAndReplace(r"genesee avenue and", "genesee avenue -", "Location", data)
searchAndReplace(r"geneva(?! hall)", "geneva hall", "Location", data)
searchAndReplace(r"geneval", "geneva", "Location", data)
searchAndReplace(r"scholars north", "scholars drive north", "Location", data)
searchAndReplace(r"scholars south", "scholars drive south", "Location", data)
searchAndReplace(r"sme", "structural and materials engineering", "Location", data)
searchAndReplace(r"bsb", "biomedical science building", "Location", data)
searchAndReplace(r" on ", " - ", "Location", data)
searchAndReplace(r"mandell", "mandel", "Location", data)
searchAndReplace(r"turn around", "loop", "Location", data)
searchAndReplace(r"turn - around", "loop", "Location", data)
searchAndReplace(r"peterson lecture hall", "peterson hall", "Location", data)
searchAndReplace(r"petson hall", "peterson hall", "Location", data)
searchAndReplace(r"petes", "peets", "Location", data)
searchAndReplace(r"turnaround", "loop", "Location", data)
searchAndReplace(r"store front", "storefront", "Location", data)
searchAndReplace(r"theatre", "theater", "Location", data)
searchAndReplace(r"atms", "atm", "Location", data)
searchAndReplace(r"bathrooms", "bathroom", "Location", data)
searchAndReplace(r"jama", "jamba", "Location", data)

# %%
searchAndReplace(r"^applies physics and math$", "applied physics and mathematics building", "Location", data)

# %%
pines = [
    'pines dining',
    'pines dining hall',
    'pines dinning hall',
    'pines of la jolla',
    'pines on muir commons',
    'pines restaurant',
    'pines - muir commons',
]
for t in pines:
    searchAndReplace(r"^{}$".format(t), "pines", "Location", data)

# %%
searchAndReplace(r"argo and blake hall", "argo hall - black hall", "Location", data)
searchAndReplace(r"argo hall and blake hall", "argo hall - black hall", "Location", data)
searchAndReplace(r"i house", "international house", "Location", data)
searchAndReplace(r"artist lane", "artists lane", "Location", data)
searchAndReplace(r"asante house", "asante hall", "Location", data)
searchAndReplace(r"asante(?! hall)", "asante hall", "Location", data)
searchAndReplace(r"earth south", "earth hall south", "Location", data)
searchAndReplace(r"giesel", "geisel", "Location", data)
searchAndReplace(r"madeville", "mandeville", "Location", data)
searchAndReplace(r"meyers", "myers", "Location", data)
searchAndReplace(r"olsen", "osler", "Location", data)
searchAndReplace(r"villa la jolla(?! drive)", "villa la jolla drive", "Location", data)
searchAndReplace(r"la jolla la jolla", "villa la jolla drive", "Location", data)
searchAndReplace(r"blacks gold", "blackgold", "Location", data)
searchAndReplace(r"black gold", "blackgold", "Location", data)
searchAndReplace(r"blackgold(?! road)", "blackgold road", "Location", data)
searchAndReplace(r"green tree", "greentree", "Location", data)
searchAndReplace(r"villa loa", "villa la", "Location", data)
searchAndReplace(r"jo0lla", "jolla", "Location", data)
searchAndReplace(r"vigt", "voigt", "Location", data)
searchAndReplace(r"villa mallorca", "via mallorca", "Location", data)
searchAndReplace(r"villa la jolla(?! drive)", "villa la jolla drive", "Location", data)
searchAndReplace(r"marsahll", "marshall", "Location", data)
searchAndReplace(r"marshal ", "marshall ", "Location", data)
searchAndReplace(r"apartmest", "apartments", "Location", data)
searchAndReplace(r"enginerring", "engineering", "Location", data)
searchAndReplace(r"equalit ", "equality ", "Location", data)
searchAndReplace(r"communter ", "commuter ", "Location", data)
searchAndReplace(r"gillman", "gilman", "Location", data)
searchAndReplace(r"finanacial", "financial", "Location", data)
searchAndReplace(r"boigt", "voigt", "Location", data)
searchAndReplace(r"eucalyptus lane", "eucalyptus grove lane", "Location", data)
searchAndReplace(r"eucalyptus grove$", "eucalyptus grove lane", "Location", data)
searchAndReplace(r"eucalyptus$", "eucalyptus grove lane", "Location", data)
searchAndReplace(r"matthew(?!s)", "matthews", "Location", data)

# %%
searchAndReplace(r"goldberg apartments", "goldberg hall", "Location", data)
searchAndReplace(r"goldberg complex", "goldberg hall", "Location", data)
searchAndReplace(r"goldberg$", "goldberg hall", "Location", data)
searchAndReplace(r"goldbarg$", "goldberg", "Location", data)
searchAndReplace(r"warren - goldberg hall$", "goldberg hall", "Location", data)
searchAndReplace(r"warren apartments - goldberg hall$", "goldberg hall", "Location", data)
searchAndReplace(r"warren goldberg$", "goldberg hall", "Location", data)
searchAndReplace(r", voigt drive$", " - voigt drive", "Location", data)
searchAndReplace(r"bike lot", "bike rack", "Location", data)
searchAndReplace(r"argo hall - black hall", "argo hall - blake hall", "Location", data)
searchAndReplace(r"blake lounge", "blake hall - lounge", "Location", data)
searchAndReplace(r"blake area", "bike rack", "Location", data)
searchAndReplace(r"brenna hall", "brennan hall", "Location", data)
searchAndReplace(r"brown h all", "brown hall", "Location", data)
searchAndReplace(r"campus service complex", "campus services complex", "Location", data)
searchAndReplace(r"canyon view", "canyonview", "Location", data)
searchAndReplace(r"caps(?! office)", "caps office", "Location", data)
searchAndReplace(r"challenger fleet", "challenger hall", "Location", data)
searchAndReplace(r"challenger suite", "challenger hall", "Location", data)
searchAndReplace(r"cuzco house", "cuzco hall", "Location", data)
searchAndReplace(r"ehands", "environmental health and safety", "Location", data)

# %%
searchAndReplace(r"argo residential hall", "argo hall", "Location", data)
searchAndReplace(r"baseball field parking lot", "baseball field - lot 701", "Location", data)
searchAndReplace(r"basket ball", "basketball", "Location", data)
searchAndReplace(r"basketball(?! court)", "basketball court", "Location", data)
searchAndReplace(r"courts", "court", "Location", data)
searchAndReplace(r"colelge", "college", "Location", data)
searchAndReplace(r"clincal", "clinical", "Location", data)
searchAndReplace(r"stepehn", "stephen", "Location", data)
searchAndReplace(r"studedent", "student", "Location", data)
searchAndReplace(r"court yard", "- court yard", "Location", data)
searchAndReplace(r"bimedical", "biomedical", "Location", data)
searchAndReplace(r"lebon(?! drive)", "lebon drive", "Location", data)
searchAndReplace(r"carolines(?! seaside)", "carolines seaside", "Location", data)
searchAndReplace(r"carolines seaside(?! cafe)", "carolines seaside cafe", "Location", data)
searchAndReplace(r"urey(?! hall)", "urey hall", "Location", data)
searchAndReplace(r"villa lo jolla", "villa la jolla drive", "Location", data)
searchAndReplace(r"sturcture", "structure", "Location", data)
searchAndReplace(r"glabraith", "galbraith", "Location", data)
searchAndReplace(r" restaurant", "", "Location", data)
searchAndReplace(r"buildng", "building", "Location", data)
searchAndReplace(r"middle earth(?! hall)", "middle earth hall", "Location", data)
searchAndReplace(r"middle east(?! hall)", "middle east hall", "Location", data)
searchAndReplace(r"miaramar", "miramar", "Location", data)
searchAndReplace(r"i - 1", "i-1", "Location", data)
searchAndReplace(r"mobile", "mobil", "Location", data)
searchAndReplace(r"mtf", "medical training facility", "Location", data)
searchAndReplace(r"extensions", "extension", "Location", data)
searchAndReplace(r"ucsd extension", "university extension", "Location", data)
searchAndReplace(r"ucsd extension(?! complex)", "university extension complex", "Location", data)
searchAndReplace(r"campus pt", "campus point", "Location", data)
searchAndReplace(r"comlex", "complex", "Location", data)
searchAndReplace(r"comples", "complex", "Location", data)
searchAndReplace(r"fueld", "fuel", "Location", data)
searchAndReplace(r"unex building", "university extension complex", "Location", data)
searchAndReplace(r"unex", "university extension complex", "Location", data)
searchAndReplace(r"gym", "gymnasium", "Location", data)
searchAndReplace(r"rec ", "recreation ", "Location", data)
searchAndReplace(r"recreation center", "recreation gymnasium", "Location", data)
searchAndReplace(r"leichtag biochemical", "leichtag biomedical", "Location", data)
searchAndReplace(r"leichtag biological", "leichtag biomedical", "Location", data)
searchAndReplace(r"leichtag(?! biomedical)", "leichtag biomedical", "Location", data)
searchAndReplace(r"leichtag biomedical(?! research)", "leichtag biomedical research", "Location", data)
searchAndReplace(r"leichtag biomedical research building", "leichtag biomedical research", "Location", data)
searchAndReplace(r"structureal", "structural", "Location", data)
searchAndReplace(r"student center building", "student center", "Location", data)
searchAndReplace(r"tuolumne(?! apartments)", "tuolumne apartments", "Location", data)
searchAndReplace(r"trition", "triton", "Location", data)
searchAndReplace(r"tuolumne(?! apartments)", "tuolumne apartments", "Location", data)
searchAndReplace(r"log 306", "lot 306", "Location", data)
searchAndReplace(r" \(off campus\)", "", "Location", data)
searchAndReplace(r"play house", "playhouse", "Location", data)
searchAndReplace(r"co - op", "coop", "Location", data)
searchAndReplace(r"hss", "humanities and social sciences", "Location", data)
searchAndReplace(r"humanities and social sciences building", "humanities and social sciences", "Location", data)
searchAndReplace(r"humanities and social science(?!s)", "humanities and social sciences", "Location", data)
searchAndReplace(r"hy thai", "hi thai", "Location", data)
searchAndReplace(r"hai thai", "hi thai", "Location", data)
searchAndReplace(r"hi - thai", "hi thai", "Location", data)
searchAndReplace(r"hi tai", "hi thai", "Location", data)
searchAndReplace(r"la jolla scenic road", "la jolla scenic drive", "Location", data)
searchAndReplace(r"la jolla scenic(?! drive)", "la jolla scenic drive", "Location", data)
searchAndReplace(r"humanitites", "humanities", "Location", data)
searchAndReplace(r"la jolla shores road", "la jolla shores drive", "Location", data)
searchAndReplace(r"lgtb", "lgbt", "Location", data)
searchAndReplace(r"muir - biology building", "biology building", "Location", data)
searchAndReplace(r"muir - ledden auditorium", "ledden auditorium", "Location", data)
searchAndReplace(r"muir - ledden auditorium", "ledden auditorium", "Location", data)
searchAndReplace(r"^biology$", "biology building", "Location", data)
searchAndReplace(r"^beagle$", "beagle hall", "Location", data)
searchAndReplace(r"^beagle building - revelle$", "beagle hall", "Location", data)
searchAndReplace(r"^beagle dorm housing$", "beagle hall", "Location", data)
searchAndReplace(r"^beagle residential hall$", "beagle hall", "Location", data)
searchAndReplace(r"^beagle lounge$", "beagle hall - lounge", "Location", data)
searchAndReplace(r"structural and engineering", "structural and materials engineering", "Location", data)
searchAndReplace(r"structural and material engineering", "structural and materials engineering", "Location", data)
searchAndReplace(r"structural and material engineer(?!ing)", "structural and materials engineering", "Location", data)
searchAndReplace(r"structural material engineering", "structural and materials engineering", "Location", data)
searchAndReplace(r"structural materials engineering building", "structural and materials engineering", "Location", data)

# %%
searchAndReplace(r"natural science(?!s)", "natural sciences", "Location", data)
searchAndReplace(r"natural sciences(?! building)", "natural sciences building", "Location", data)
searchAndReplace(r"natual", "natural", "Location", data)
searchAndReplace(r"new student center", "student services center", "Location", data)
searchAndReplace(r"new student center", "student services center", "Location", data)
searchAndReplace(r"(?<!parking )lot", "parking lot", "Location", data)
searchAndReplace(r"e grove", "eucalyptus grove", "Location", data)
searchAndReplace(r"la jolla villa(?!ge)", "la jolla village", "Location", data)
searchAndReplace(r"la jolla village(?! drive| square)", "la jolla village drive", "Location", data)
searchAndReplace(r"la jolla shores pl(?!ayground)", "la jolla shores playground", "Location", data)
searchAndReplace(r"la jolla nobel apartments", "la jolla shores playground", "Location", data)
searchAndReplace(r"cmm", "cellular and molecular medicine", "Location", data)
searchAndReplace(r"cncb", "center for neural circuits and behavior", "Location", data)
searchAndReplace(r"cmrr", "center for memory and recording research", "Location", data)
searchAndReplace(r"cmg", "center for neural circuits and behavior", "Location", data)
searchAndReplace(r"super computer", "supercomputer", "Location", data)
searchAndReplace(r"(?<!san diego )supercomputer", "san diego supercomputer", "Location", data)
searchAndReplace(r"supercomputer(?! center)", "supercomputer center", "Location", data)
searchAndReplace(r"cuzco(?! hall)", "cuzco hall", "Location", data)
searchAndReplace(r"kathmandu apartments", "kathmandu hall", "Location", data)
searchAndReplace(r"kathmandu house", "kathmandu hall", "Location", data)
searchAndReplace(r"kathmandu(?! hall)", "kathmandu hall", "Location", data)
searchAndReplace(r"american", "america", "Location", data)
searchAndReplace(r"latin america(?! hall)", "latin america hall", "Location", data)
searchAndReplace(r"erc admin(?!istration)", "erc administration", "Location", data)
searchAndReplace(r"erc africa hall", "africa hall", "Location", data)
searchAndReplace(r"erc - cuzco", "cuzco", "Location", data)
searchAndReplace(r"erc asante hall", "asante hall", "Location", data)
searchAndReplace(r"erc latin america", "latin america", "Location", data)
searchAndReplace(r"mesa verde apartments", "mesa verde", "Location", data)
searchAndReplace(r"mesa verde hall", "mesa verde", "Location", data)
searchAndReplace(r"applied physics and mathematics building", "applied physics and mathematics", "Location", data)
searchAndReplace(r"^economics$", "economics building", "Location", data)
searchAndReplace(r"norty", "north", "Location", data)
searchAndReplace(r"^center for neural circuits$", "center for neural circuits and behavior", "Location", data)
searchAndReplace(r"^center for molecular genetics$", "center for neural circuits and behavior", "Location", data)
searchAndReplace(r"^molecular genetics$", "center for neural circuits and behavior", "Location", data)
ser = [
    'science and engineering',
    'science and engineering building - price center',
    'science and engineering research',
    'science and engineering research building',
    'science and engineering research facility',
]
for t in ser:
    searchAndReplace(r"^{}$".format(t), "science and engineering research facility", "Location", data)
ser = [
    'health sciences biomed research',
    'health sciences biomed research facilities',
    'health sciences biomed research facility',
    'health sciences biomedical research',
    'health sciences biomedical research facility',
    'health sciences building',
    'health science',
    'health science biomedical research',
]
for t in ser:
    searchAndReplace(r"^{}$".format(t), "science and engineering research facility", "Location", data)
searchAndReplace(r"internal medicine group", "school of medicine", "Location", data)
searchAndReplace(r"img", "school of medicine", "Location", data)
searchAndReplace(r"la jolla professional complex", "la jolla professional center", "Location", data)
searchAndReplace(r"^la jolla institute for allergy$", "la jolla institute for allergy and immunology", "Location", data)
searchAndReplace(r"la jolla institute of allergy", "la jolla institute for allergy and immunology", "Location", data)
searchAndReplace(r"^institute for allergy$", "la jolla institute for allergy and immunology", "Location", data)
searchAndReplace(r" at ", " - ", "Location", data)
searchAndReplace(r" @ ", " - ", "Location", data)
searchAndReplace(r"^santorini$", "santorini island grill", "Location", data)
searchAndReplace(r"ventana(?!s)", "ventanas", "Location", data)
searchAndReplace(r"lots", "lot", "Location", data)
searchAndReplace(r"pangea parking(?! structure)", "pangea parking structure", "Location", data)
searchAndReplace(r"^pangea park$", "pangea parking structure", "Location", data)
searchAndReplace(r"^pangea$", "pangea parking structure", "Location", data)
searchAndReplace(r"parmaceutical", "pharmaceutical", "Location", data)
searchAndReplace(r"perlman medical center", "perlman ambulatory care center", "Location", data)
searchAndReplace(r"perlman ambulatory care(?! center)", "perlman ambulatory care center", "Location", data)
searchAndReplace(r"iggp", "institute of geophysics and planetary physics", "Location", data)
searchAndReplace(r"inter - tribal", "intertribal", "Location", data)
searchAndReplace(r"black resources", "black resource", "Location", data)
searchAndReplace(r"black student", "black", "Location", data)
searchAndReplace(r"resouce", "resource", "Location", data)
searchAndReplace(r"bjs pizza", "bjs", "Location", data)
bioeng = [
    'bio - engineering building',
    'bio engineering building',
    'bioengineering building',
    'bioengineering hall',
    'powell - focht bioengineering building',
    'powell - focht bioengineering hall',
    'powell focht building',
    'ebu 3a',
    'ebu3a',
]
for t in bioeng:
    searchAndReplace(r"^{}$".format(t), "powell-focht bioengineering hall", "Location", data)
searchAndReplace(r"powell focht", "powell-focht bioengineering hall", "Location", data)
searchAndReplace(r"bioengineering building", "powell-focht bioengineering hall", "Location", data)
searchAndReplace(r"black resources", "black resource", "Location", data)
searchAndReplace(r"black student", "black", "Location", data)
searchAndReplace(r"resouce", "resource", "Location", data)
searchAndReplace(r"bjs pizza", "bjs", "Location", data)

# %%
searchAndReplace(r"\(off - campus\)", "resource", "Location", data)
searchAndReplace(r" - drive", " drive", "Location", data)
searchAndReplace(r"drive drive", "drive", "Location", data)
searchAndReplace(r"mahalia", "mahaila", "Location", data)
searchAndReplace(r"mahaila drive", "mahaila avenue", "Location", data)
searchAndReplace(r"mahaila(?! avenue)", "mahaila avenue", "Location", data)
searchAndReplace(r"gilder port", "glider port", "Location", data)
searchAndReplace(r"myers(?! drive| lane)", "myers lane", "Location", data)
searchAndReplace(r"myers lane", "myers drive", "Location", data)
searchAndReplace(r"roundtable", "round table", "Location", data)
searchAndReplace(r"rosecrans(?! street)", "rosencrans street", "Location", data)
searchAndReplace(r"rockbottom", "rock bottom", "Location", data)
searchAndReplace(r"rock bottom(?! brewery)", "rock bottom brewery", "Location", data)
searchAndReplace(r"rock bottom brewery driveway", "rock bottom brewery", "Location", data)
searchAndReplace(r"robinson complex building", "robinson building complex", "Location", data)
searchAndReplace(r"robinson complex", "robinson building complex", "Location", data)
rp = [
    'robert pain center',
'robert pain center - forum auditorium',
'robert pain center - seaside forum',
'robert paine cancer center',
'robert paine center',
'robert paine center - seaside forum',
'forum - robert paine center',
'robert paine center forum auditorium',
'paine auditorium',
]
for t in rp:
    searchAndReplace(r"^{}$".format(t), "robert paine scripps forum for science, society and the environment", "Location", data)
rtr = [
    'rita apartments',
    'rita atkinson',
    'rita atkinson hall',
    'rita atkinson residential',
    'rita atkinson residentials',
    'rita atkinsons',
]
for t in rtr:
    searchAndReplace(r"^{}$".format(t), "rita atkinson residences", "Location", data)
searchAndReplace(r"rita north - bike rack", "rita atkinson residences - bike rack", "Location", data)
searchAndReplace(r"dock doc", "dock", "Location", data)
stgm = [
    'saint germaines',
    'saint germaines - holiday court',
    'saint germains',
    'saint germains store',
    
]
for t in stgm:
    searchAndReplace(r"^{}$".format(t), "saint germaines", "Location", data)
searchAndReplace(r"salk overflow", "salk", "Location", data)
searchAndReplace(r"salk(?! institute)", "salk institute", "Location", data)
searchAndReplace(r"robinson(?= [\d])", "robinson building complex", "Location", data)
searchAndReplace(r"scholar drive", "scholars drive", "Location", data)
searchAndReplace(r"scholar drive", "scholars drive", "Location", data)
searchAndReplace(r"(?<!the )village east", "the village east", "Location", data)
searchAndReplace(r"(?<!the )village west", "the village east", "Location", data)
searchAndReplace(r"village east(?! building)", "village east building", "Location", data)
searchAndReplace(r"village west(?! building)", "village west building", "Location", data)
searchAndReplace(r"1 mirmar building", "one miramar building", "Location", data)
searchAndReplace(r"$1 ", "", "Location", data)
searchAndReplace(r"$p - ", "parking lot ", "Location", data)
searchAndReplace(r"b - ball", "basketball ", "Location", data)
searchAndReplace(r"isascs", "isaacs", "Location", data)
searchAndReplace(r"venter", "ventner", "Location", data)
searchAndReplace(r"keeling(?! apartments)", "keeling apartmnets", "Location", data)
searchAndReplace(r"visitorparking", "visitor parking", "Location", data)



searchAndReplace(r"village drives", "village drive", "Location", data)
searchAndReplace(r"vllage", "village", "Location", data)







#searchAndReplace(r"(?<![a-z])va (?!hospital)", "va hospital", "Location", data)

# %%
#data.to_csv("aggregate.csv", index=False)

# %%
for i in data[data.Location == 'unknown trouble'].index:
    data.Location.loc[i] = "unknown location"

# %%
data.Location.loc[17985] = "unknown location"
data.Location.loc[23661] = "unknown location"
data.Location.loc[9494] = "unknown location"
data.Location.loc[30015] = "unknown location"
data.Location.loc[9494] = "unknown location"
data.Location.loc[19805] = "unknown location"
data.Location.loc[21249] = "unknown location"

data.Event.loc[37709] = "incomplete call"
data.Location.loc[37709] = "unknown location"
data.Location.loc[9934] = "unknown location"

# %%
data[data.Location == "incomplete wireless 911 call"]
# Out:
# Empty DataFrame
# Columns: [Event, Location, Date Reported, Incident/Case#, Date Occurred, Time Occurred, Summary:, Disposition:]
# Index: []

# %%
searchAndReplace(r"‚äô", "'", "Summary:", data)

# %%
data.to_csv("aggregate.csv", index=False)

# %%
manualchecking(data)

# %% [markdown]
# check values '10 - 23 - 14',
# '11 - 22 - 2013',
# '120728040',
# 2015 - 0344,
# 'unknown trouble',
# 'incomplete
# verbal warning issued
