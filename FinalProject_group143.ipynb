# %% [markdown]
# # OVERVIEW #

# %% [markdown]
# #### We can all agree that housing plays an essential role when it comes to settling down and starting a family and while looking for housing, people take many different preferences into consideration. We wanted to investigate these population preferences across San Diego County; our process will be breaking down the current housing map out of the area. In addition, we will be considering and highlighting the attractions and accomodations that greatly influence peoples’ decisions to settle in certain areas of San Diego County. Specifically we wanted to consider the factors of race, age, income, and family size when it came to choosing an area to live and through this research, we hope to underline the psychology and nuances of the housing preferences and ultimately bring about insights of how these factors interact.

# %% [markdown]
# ## NAMES ##

# %% [markdown]
# #### Danny Wang ####
# #### Nikhil Ranjan ####
# #### Andre Lopez ####
# #### Ezra Chung ####
# #### HongSeok Oh ####

# %% [markdown]
# ## Group Members IDs ##

# %% [markdown]
# #### A13435251
# #### A15752182
# #### A15753302
# #### A13676342
# #### A15759616

# %% [markdown]
# # Research Question

# %% [markdown]
# ### Over the past decade how has the characterization of the greater San Diego has changed in the socio-economic values of people? In particular how do factors such as age, income, racial diversity influence of movement within certain parts of San Diego?

# %% [markdown]
# # Background and Prior Work#

# %% [markdown]
# #### As we were thinking of a question that we wanted to answer, our main criteria was that the question should center around something that we all associated with. Coming from different stories on how we entered the San Diego region, we felt that it was best to delve into a topic that resonated in our minds as we entered the coming school year. Furthermore, housing is also a staple in the acclimation process of an individual to a new environment.
#
#
# #### While looking into housing, particularly in the San Diego region, we found multiple censuses on the population of San Diego and we began to find patterns through time on how populations settled and preferred certain locations. Business managers, schools, and apartment complexes have used these censuses to develop an idea on where to set up their business. These changes in the population, among many other impacting factors, have continuously altered the formation and opportunities of San Diego over the past decade. Current data shows impacts of individual comparisons, including income and location, and its effects on where individuals and families decide to live. Thus, as residents of San Diego, it has become part of our interest to discover what areas cater best to specific demographics of our considering factors of race, age, and income. Our data and research will create an accurate model of the current housing market of San Diego County which will be essential for renters and buyers because it will help them map out the different options and offerings of each area. In addition, this model will simplify the housing hunting process for students. ####

# %% [markdown]
# ### References

# %% [markdown]
# #### 1) https://www.globest.com/2018/06/29/san-diegos-population-growth-is-slowing/?slreturn=20190509142758
# #### 2) https://www.voiceofsandiego.org/neighborhoods/how-san-diegos-changing-in-three-charts/

# %% [markdown]
# # Hypothesis #

# %% [markdown]
# #### Since we want to observe the changes of socio-economic environment of the San Diego County, we will mainly explore and hypothesize the distribution of population based on income, age, and race. From all the data we will gather, we should be able to predict correlations between where a certain group of demographics live and why they live there. Knowing that San Diego is the largest city in the county, we predict that the city will have the highest median income as well as being the most populated. In addition, we believe that the majority of Chula Vista residents consist of older, retired people. Overall in the county, we anticipate that the percentage of Caucasians will decrease because of increased immigration of other ethnicities including Asians and Hispanics.

# %% [markdown]
# # Datasets:

# %% [markdown]
# ### American FactFinder

# %% [markdown]
# #### https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?pid=DEC_00_PL_GCTPL.CY07&prodType=table
# #### This dataset contains over 1,000 data points pertaining to the demographic distribution of San Diego County. Variables of the dataset include the different races residing in SD County which are indexed by census tracts taken over different areas of San Diego County. We took data from 2000 and 2010's consensuses to show the changes if the county over the decade.
# #### Dataset is culmination of data from 2000 to 2017. Contains most information for San Diego County needed for this project. Will be used to combine with later years to find correlations and changes.

# %% [markdown]
# ### Demographic Profiles of 2016

# %% [markdown]
# #### https://www.sandiegocounty.gov/content/dam/sdc/hhsa/programs/phs/CHS/demographics/FINAL_2016_Demographic_Profiles_1.30.18.pdf
# #### This dataset contains over 10,000 observations on the age distribution of San Diego County further broken down into the cities of the county. This set also has displays the occupation distribution of San Diego County from 2012 to 2016 allowing us to better represent the county over the past years. The sources of these observations is from the Health and Human Services Agency of San Diego County.
# #### This demographic data includes basic population characteristics like age, gender, race, and education. Also important data on Income and Poverty which includes labor force, poverty level, and renter occupancy.
# #### Although this data set represents data from 2012 to 2016, we still want as much data available to display the differences and relations. So we would combine more data from other years but the same categories in respect to a demographic context to show year over year.

# %% [markdown]
# ### Income Breakdown
# #### https://www.deptofnumbers.com/income/california/san-diego/
# #### This site has about 100 observations of the incomes in San Diego County over the past year and compares them to California and US averages. We utilized the "Historical Inflation Adjusted Median Household Income for San Diego" chart in intro of anaylsis to layout our factors we are analyzing in our hypothesis. The source of the data is from the Department of Numbers, a public dataset.

# %% [markdown]
# ### Demographic Breakdown
# #### https://www.sandag.org/uploads/publicationid/publicationid_2001_20213.pdf
# #### This source has graphs and charts of over 500 observations ranging from total populaion of San Diego County, population change, and demographic stats. We used the data of San Diego different demographic population numbers provided in one of the charts listed on the site. The source of this data is from the San Diego Association of Governments (SANDAG).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import pylab as pl
import matplotlib.pyplot as plot
from pandas import ExcelWriter
from pandas import ExcelFile

# %% [markdown]
# # Data Cleaning And Visualization

# %% [markdown]
# ### With the scope of our analysis limited to the factors of age, income, education, diversity and housing, we will first display the data of each factor on the broadest scale. Modeled below, we show the increase of income in San Diego County from 2006 to 2016. We note the dip that started around 2008 with the housing crisis.

# %%
df1 = pd.read_excel('historical_InflationSD.xlsx')
graph1 = df1.plot.line(x = "Year", y = "Income",title = "Graph 1: Change in Income SD County 2006 to 2016",figsize=(7,7))
plot.ylabel('Income ($)',fontsize=12)
# Out:
# Text(0, 0.5, 'Income ($)')

# %% [markdown]
# ### In the next graph, we plotted the population of each city in a 5 year estimate from 2012 to 2016. We can see that San Diego is the largest city in SD County.

# %%
df2 = pd.read_excel('SDcitiesPopulations.xlsx')
df2 = df2.drop([17])    #drop Unincorporated entry 
graph2 = df2.plot.bar(x = "Cities", y = "Population", title = "Graph 2: 5 Year Estimate of SD County Cities Populations", legend = False ,figsize=(7,7))
plot.ylabel('Population',fontsize=12)
# Out:
# Text(0, 0.5, 'Population')

# %% [markdown]
# ### In our final graph, we display the age breakdown of the cities of San Diego County from 2012 to 2016. We note that the largest age group appears to be ages 25-44.

# %%
df3 = pd.read_excel('SDcountyAgeBreakdown.xlsx')
df3 = df3.drop(columns = ['0-4N', '5-14N', '15-24N', '25-44N','45-64N', '65+N']) #Remove number columns, only want percentagesdf3 = 
df3 = df3.rename(columns={'0-4P': 'Ages 0-4', '5-14P': 'Ages 5-14', '15-24P': 'Ages 15-24', '25-44P': 'Ages 25-44','45-64P': 'Ages 45-64', '65+P': 'Ages 65+'})
graph3 = df3.plot(kind = 'bar', title = "Graph 3: Age Breakdown of SD County 2012 to 2016", stacked = True, x = "Cities", figsize=(7,7)).legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plot.ylabel('Percentage',fontsize=12)
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ## Data Cleaning For Change in Population and Housing Units

# %% [markdown]
# #### This sheet was taken from the Census Bureau and SANDAG. Only the datasheet from the Census Bureau was cleaned. We first dropped a column we didn't need, no real quantifiable data. We then only filtered the data that pertained to 'San Diego County.' Lastly we took out any small values that were not going to help with visualization and then created a final dataframe with the population count.
#
# #### The graph below did not need to have its sheet cleaned, as it only had 5 data points representing the amount of building permits were approved.

# %%
populationdf = pd.read_excel('PopulationOverTheYears.xlsx')
populationdf.columns = ['id', 'City','type','variable','Population Count','Year']
populationdf = populationdf.drop(['id'], axis=1)

populationdf = populationdf[populationdf['City'] == 'San Diego County, California']
populationdf['Population Count'] = populationdf['Population Count'].astype(float)
popChangedf = populationdf[populationdf['Population Count'] < 5]
populationdf2 = populationdf[populationdf['variable'] == 'count']

graph6 = populationdf2.plot.line(x='Year',y='Population Count',title = "Graph 4: Population Change 2009 to 2013",figsize = (8,8),marker ='o',ylim=(2800000,3400000),grid=True)
plot.ylabel('Population',fontsize=12)
print(populationdf2) # population san diego

#----------------------------------------------------------------------------------------------------------------------#
housingdf = pd.read_excel('Housing.xlsx')
housingdf.columns = ['Year','Units']
graph7 = housingdf.plot.line(x='Year',y='Units',title = "Graph 5: Number of Housing Units 2013 to 2017",figsize = (8,8),marker ='o',grid=True)
plot.ylabel('Number of Units',fontsize=12)
print(housingdf)
# Out:
#                            City    type variable  Population Count  Year
# 0  San Diego County, California  county    count         3138265.0  2013
# 2  San Diego County, California  county    count         3100500.0  2012
# 4  San Diego County, California  county    count         3060849.0  2011
# 6  San Diego County, California  county    count         3022468.0  2010
# 8  San Diego County, California  county    count         2987543.0  2009
#    Year  Units
# 0  2013   3132
# 1  2014   2115
# 2  2015   4403
# 3  2016   4459
# 4  2017   5865

# %% [markdown]
# #### These graphs are connected to each other. We wanted to show the influx of people coming into San Diego. As we see over the years, there was a steady but large increase of people moving into San Diego. The graph below the population graph shows the amount of building permits(units) were approved to buiild more housing. This visualization just shows there more people moving here and we want to see where they prefer to settle down.

# %% [markdown]
# ## Data Cleaning For Income Region Breakdown

# %% [markdown]
# #### This dataset was retrieved from SANDAG. The excel was practicall clean as it directly pertained to Income. All we did was drop the NaN values, labeled the columns. Deleted specific cities and only plotted the averages of the major regions as it still got main point across

# %%
incomeregdf = pd.read_excel('IncomeRegion.xlsx')

incomeregdf = incomeregdf.dropna()

incomeregdf.columns =['Region', 'Median Household Income']
incomeregdf = incomeregdf[incomeregdf['Region'].isin(['Central Region','East Region', 'North Central Region', 'North Coastal Region', 'North Inland Region', 'South Region'])]
incomeregdf.set_index('Region', inplace=True)
graph10 = incomeregdf.plot(kind='barh', title = "Graph 6: Household Income Distribution",figsize=(10,7), fontsize=13);
graph10.set_xlabel("Median Household Income",fontsize=12)
graph10.set_ylabel("Region",fontsize=12)
print(incomeregdf)
# Out:
#                       Median Household Income
# Region
# Central Region                          53523
# East Region                             66663
# North Central Region                    87963
# North Coastal Region                    76602
# North Inland Region                     79116
# South Region                            62418

# %% [markdown]
# #### This data shows the average Median Household Income in San Diego. This data was collected from 2012 to 2016. Although we can see that the bars are close enough, in a monetary context, there is definitely a disparity in income in these regions. Just from this graph we can tell certain people of certain incomes, stay in a certain region.

# %% [markdown]
# ## Data Cleaning For Job/Occupation Region Breakdown

# %% [markdown]
# #### This data was also retrieved from SANDAG. This dataset was also pretty organized. The only cleaning we had to do was with organizing the columns and setting the index.

# %%
jobregdf = pd.read_excel('JobByRegion.xlsx')

jobregdf.columns =['Region', 'Agriculture','Construction','Manufacturing','Wholesale','Retail','Transportation','Information','Finance','Scientific','Educational','Entertainment','Other']
jobregdf = jobregdf[jobregdf['Region'].isin(['Central Region','East Region', 'North Central Region', 'North Coastal Region', 'North Inland Region', 'South Region'])]
jobregdf.set_index('Region', inplace=True)
graph4 = jobregdf.plot(kind = 'bar', title = "Graph 7: Occupation Breakdown", stacked = True,figsize=(7,7)).legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plot.ylabel('Percentage',fontsize=12)
print(jobregdf)
# Out:
#                       Agriculture  Construction  Manufacturing  Wholesale  \
# Region
# Central Region              0.006         0.052          0.067      0.017
# East Region                 0.005         0.080          0.076      0.022
# North Central Region        0.003         0.036          0.097      0.023
# North Coastal Region        0.015         0.053          0.116      0.032
# North Inland Region         0.022         0.067          0.116      0.029
# South Region                0.004         0.058          0.083      0.029
#
#                       Retail  Transportation  Information  Finance  \
# Region
# Central Region         0.104           0.039        0.022    0.054
# East Region            0.130           0.049        0.018    0.060
# North Central Region   0.086           0.030        0.030    0.074
# North Coastal Region   0.112           0.031        0.024    0.065
# North Inland Region    0.103           0.033        0.024    0.061
# ...

# %% [markdown]
# #### This graph is a representation of breakdown of the major regions of San Diego in relation to Occupation/Job. As we see each bar is broken down by occupation. The more bar taken up by a certain color, the more percentage of occupation in that region. As we see, each region has its own characteristics. Central has more agriculture, while North Central has more Educational and Scientific. This visualization helps us understand how these cities are broken down by jobs, and similarities on jobs and where those people live.

# %% [markdown]
# ## Data Cleaning for Race By Region Sheet

# %% [markdown]
# #### This graph was retrieved from SANDAG. Unfortunately I had to clean the data in Excel as I had trouble retrieving the data from the pdf to excel. I had to manually enter the input into this excel file.

# %%
raceregdf = pd.read_excel('RaceByRegion.xlsx')
raceregdf.columns = ['Geography','Hispanic(#)','Hispanic(%)','White(#)','White(%)','Black(#)','Black(%)','API(#)','API(%)','Other(#)','Other(%)']
raceregdf = raceregdf.drop(['Hispanic(%)','White(%)','Black(%)','API(%)','Other(%)'], axis=1)
raceregdf.set_index('Geography', inplace=True)
graph11 = raceregdf.plot(kind = 'bar', title = "Graph 11: Ethnicity Breakdown by Region", stacked = True,figsize=(7,7)).legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plot.ylabel('Population Count',fontsize=12)
raceregdf.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a580efe2_8d48_11e9_97f5_4a53f6020b8c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Hispanic(#)</th>
#         <th class="col_heading level0 col1" >White(#)</th>
#         <th class="col_heading level0 col2" >Black(#)</th>
#         <th class="col_heading level0 col3" >API(#)</th>
#         <th class="col_heading level0 col4" >Other(#)</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Geography</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a580efe2_8d48_11e9_97f5_4a53f6020b8clevel0_row0" class="row_heading level0 row0" >Central Region</th>
#         <td id="T_a580efe2_8d48_11e9_97f5_4a53f6020b8crow0_col0" class="data row0 col0" >218611</td>
# ...

# %% [markdown]
# ## Data Cleaning For Population 2000 Sheet

# %% [markdown]
# #### This data was provided by the Census Bureau. This data had a little more than we needed, so more cleaning was done. We transposed the data, as the Bureau organized it differently. We then deleted some unwanted rows. We also noticed that values were given in percentages and whole numbers, luckily they were separated in an 'every other' fashion, so we deleted every other row to save the whole number values. We then deleted any values below 10,000 as we felt that was not going to play a large role in the majority. Lastly, we made some cosmetic changes with some dropped rows and renaming for better readability.

# %%
race_2000df = pd.read_excel('populationtotals2000.xlsm')
race_2000df = race_2000df.T
race_2000df.columns = ['Race', 'Percent/Total Number']
race_2000df = race_2000df.iloc[3:] # deleted first 3 rows
race_2000df = race_2000df.iloc[::2] # deleted all percentage values
race_2000df = race_2000df.iloc[2:] # delete total population row
race_2000df['Percent/Total Number'] = race_2000df['Percent/Total Number'].astype(int)


race_2000df2 = race_2000df[race_2000df['Percent/Total Number'] > 10000] 
race_2000df2 = race_2000df2.drop(['HC01_VC07','HC01_VC12','HC01_VC13','HC01_VC14','HC01_VC15','HC01_VC16','HC01_VC18','HC01_VC17','HC01_VC35','HC01_VC38','HC01_VC39','HC01_VC41','HC01_VC42','HC01_VC43','HC01_VC44','HC01_VC45','HC01_VC46','HC01_VC47' ,'HC01_VC33','HC01_VC36'])
race_2000df3 = race_2000df2.replace(['Number; RACE - Total population - One race - White','Number; RACE - Total population - One race - Black or African American','Number; RACE - Total population - One race - American Indian and Alaska Native','Number; RACE - Total population - One race - Asian','Number; HISPANIC OR LATINO - Total population','Number; RACE - Total population - One race - Native Hawaiian and Other Pacific Islander','Number; HISPANIC OR LATINO - Total population - Hispanic or Latino (of any race)'],['White','African American/Black','American Indian','Asian', 'Hispanis/Latino','Native Hawaiian','Hispanic/Latino']) 
race_2000df3.set_index('Race', inplace=True)

race_2000df3.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Percent/Total Number</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Race</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8clevel0_row0" class="row_heading level0 row0" >White</th>
#         <td id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8crow0_col0" class="data row0 col0" >1871839</td>
#     </tr>    <tr>
#         <th id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8clevel0_row1" class="row_heading level0 row1" >African American/Black</th>
#         <td id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8crow1_col0" class="data row1 col0" >161480</td>
#     </tr>    <tr>
#         <th id="T_7d143ad2_8d48_11e9_97f5_4a53f6020b8clevel0_row2" class="row_heading level0 row2" >American Indian</th>
# ...

# %% [markdown]
# ## Data Cleaning For Population 2010 Sheet

# %% [markdown]
# #### This data was provided by the Census Bureau. This data had a little more than we needed, so more cleaning was done. We transposed the data like the one above. We then deleted some unwanted rows. Just like the sheet below, rows we wanted were separated in an 'every other' fashion, so we deleted every other row to save the whole number values. We then deleted any values below 10,000 as we felt that was not going to play a large role in the majority. We used truncate, as this was a bigger dataset and values that were needed were inbetween unneccessary data. Lastly, we made some cosmetic changes with some dropped rows and renaming for better readability.

# %%
race_2010df = pd.read_csv('2010Population.csv')

race_2010df = race_2010df.T

race_2010df.columns =['Race', 'Percent/Total Number']
race_2010df = race_2010df.iloc[3:]

race_2010df = race_2010df.iloc[::2]
race_2010df['Percent/Total Number'] = race_2010df['Percent/Total Number'].astype(int)
race_2010df2 = race_2010df[race_2010df['Percent/Total Number'] > 10000] 
race_2010df2 = race_2010df2.drop(['HD01_S01','HD01_S02','HD01_S06','HD01_S23','HD01_S24','HD01_S25','HD01_S26','HD01_S29'])
race_2010df2 = race_2010df2.truncate(before = 'HD01_S03', after = 'HD01_S30') 
race_2010df3 = race_2010df2.replace(['Number; RACE - Total population - One race - White','Number; RACE - Total population - One race - Black or African American','Number; RACE - Total population - One race - American Indian and Alaska Native','Number; RACE - Total population - One race - Asian','Number; HISPANIC OR LATINO - Total population - Hispanic or Latino (of any race)','Number; RACE - Total population - One race - Native Hawaiian and Other Pacific Islander'],['White','African American/Black','American Indian','Asian', 'Hispanic/Latino','Native Hawaiian']) 
race_2010df3.set_index('Race', inplace=True)
race_2010df3.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Percent/Total Number</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Race</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8clevel0_row0" class="row_heading level0 row0" >White</th>
#         <td id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8crow0_col0" class="data row0 col0" >1981442</td>
#     </tr>    <tr>
#         <th id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8clevel0_row1" class="row_heading level0 row1" >African American/Black</th>
#         <td id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8crow1_col0" class="data row1 col0" >158213</td>
#     </tr>    <tr>
#         <th id="T_7d22d89e_8d48_11e9_97f5_4a53f6020b8clevel0_row2" class="row_heading level0 row2" >American Indian</th>
# ...

# %% [markdown]
# ## Data Cleaning For Population 2017 Sheet

# %% [markdown]
# #### This data was provided by the Census Bureau. This data had a little more than we needed, so more cleaning was done. We transposed the data like the one above. We then deleted some unwanted rows. Just like the sheet below, rows we wanted were separated in an 'every other' fashion, so we deleted every other row to save the whole number values. We then deleted any values below 10,000 as we felt that was not going to play a large role in the majority. Lastly, we made some cosmetic changes with some dropped rows and renaming for better readability.

# %%
race_2017df = pd.read_csv('2017Population.csv')
race_2017df = race_2017df.T
race_2017df.columns =['Race', 'Percent/Total Number']
race_2017df = race_2017df.iloc[5:]
race_2017df = race_2017df.iloc[::2]

race_2017df['Percent/Total Number'] = race_2017df['Percent/Total Number'].astype(int)
race_2017df2 = race_2017df[race_2017df['Percent/Total Number'] > 10000] 
race_2017df2 = race_2017df2.drop(['HD01_VD02','HD01_VD09','HD01_VD11'])
race_2017df3 = race_2017df2.replace(['Estimate; Not Hispanic or Latino: - White alone','Estimate; Not Hispanic or Latino: - Black or African American alone','Estimate; Not Hispanic or Latino: - American Indian and Alaska Native alone','Estimate; Not Hispanic or Latino: - Asian alone','Estimate; Not Hispanic or Latino: - Native Hawaiian and Other Pacific Islander alone','Estimate; Hispanic or Latino'],['White','Black/African American','American Indian','Asian','Native Hawaiian','Hispanic/Latino'])
race_2017df3.set_index('Race', inplace=True)

race_2017df3.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_7d308318_8d48_11e9_97f5_4a53f6020b8c" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Percent/Total Number</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Race</th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_7d308318_8d48_11e9_97f5_4a53f6020b8clevel0_row0" class="row_heading level0 row0" >White</th>
#         <td id="T_7d308318_8d48_11e9_97f5_4a53f6020b8crow0_col0" class="data row0 col0" >1512229</td>
#     </tr>    <tr>
#         <th id="T_7d308318_8d48_11e9_97f5_4a53f6020b8clevel0_row1" class="row_heading level0 row1" >Black/African American</th>
#         <td id="T_7d308318_8d48_11e9_97f5_4a53f6020b8crow1_col0" class="data row1 col0" >153740</td>
#     </tr>    <tr>
#         <th id="T_7d308318_8d48_11e9_97f5_4a53f6020b8clevel0_row2" class="row_heading level0 row2" >American Indian</th>
# ...

# %% [markdown]
# ## Visualizing Change in Population from 2000 to 2017

# %%
graph3 = race_2000df3.plot.pie(y = "Percent/Total Number", figsize=(7, 7),title='Graph 8: 2000 Population Breakdown')
graph3.legend(["White","Black or African American", "American Indian and Alaska Native", "Asian","Native Hawaiian", "Hispanic/Latino"],loc='center left',bbox_to_anchor=(1.0, 0.5))
graph3.set_ylabel("")

graph4 = race_2010df3.plot.pie(y = "Percent/Total Number", figsize=(7, 7),title='Graph 9: 2010 population Breakdown')
graph4.legend(["White","Black or African American", "American Indian and Alaska Native", "Asian","Native Hawaiian" ,"Hispanic/Latino"],loc='center left',bbox_to_anchor=(1.0, 0.5))
graph4.set_ylabel("")

graph5 = race_2017df3.plot.pie(y = "Percent/Total Number", figsize=(7, 7),title='Graph 10: 2017 population Breakdown')
graph5.legend(["White","Black or African American", "American Indian and Alaska Native", "Asian", "Native Hawaiian","Hispanic/Latino"],loc='center left',bbox_to_anchor=(1.0, 0.5))
graph5.set_ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# #### These three pie charts are a product of the cleaning described above. These piecharts show a breakdown of San Diego in a racial/ethnicity context. From start to finish we see differences over the years. For example, the white population in 2000 had the majority. However as time went on, 2010 and 2017 showed great decrease in white percentages, and showed an increase of minorites, specifically those of Asian and Hispanic Origin.

# %% [markdown]
# # Data Analysis and Results

# %% [markdown]
# #### As seen above, our team took a very graphical approach with our project. We knew there would be data out there to suggest or give us an answer to our question, in how people are dispersed in San Diego. To us, the best way to do achieve that was to plot these graphs and determine if there was a correlation or not, below are a few EDA plot routes we took to investigate the correlation between some variables.

# %%
f, ax = plot.subplots(figsize=(10, 8))
corr = jobregdf.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)



f, ax = plot.subplots(figsize=(10, 8))
corr = df3.corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# #### Above are 2 correlation matrices taken for 2 of the dataframes we used for ages jobs by region. These matrices help us determine correlation coefficients which are used in statistics to measure how strong a relationship is between two variables. The diagonal elements of the matrix value are always 1, the correlation between the same columns so all the numerical attributes are important.

# %%
sns.pairplot(populationdf2)

# %% [markdown]
# #### This analysis is a representation of a bivariate distribution plot, where we can study the relationship between two variables by analyzing the scatter plot. Obviously there is a clear connection with  year and population, a positive correlation. As year increases, so does the population.

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.metrics import explained_variance_score
from sklearn.preprocessing import StandardScaler
from sklearn import linear_model
from scipy import stats
from functools import reduce
import seaborn as sn
from sklearn.metrics import confusion_matrix

df_Age = pd.read_excel('Age.xlsx', index_col = 0)
df_Job = pd.read_excel('Job.xlsx', index_col = 0)
df_Income = pd.read_excel('Income.xlsx', index_col = 0)
df_Population = pd.read_excel('Population.xlsx', index_col = 0)
df_Price = pd.read_excel('Price.xls', index_col = 0)

df_Age.index = df_Age.index.str.lower()
df_Job.index = df_Job.index.str.lower()
df_Income.index = df_Income.index.str.lower()
df_Population.index = df_Population.index.str.lower()
df_Price.index = df_Price.index.str.lower()

cities = ['carlsbad', 'chula vista', 'coronado', 'del mar', 'el cajon', 'encinitas', 'escondido', 'imperial beach',
          'la mesa', 'lemon grove', 'national city', 'oceanside', 'poway', 'san dieog', 'san marcos', 'santee', 'solana beach', 'vista']

df_Age = df_Age.loc[cities]
df_Job = df_Job.loc[cities]
df_Income = df_Income.loc[cities]
df_Population = df_Population.loc[cities]
df_Price = df_Price.loc[cities]

dfs = [df_Age, df_Job, df_Income, df_Population]
df_X =  reduce(lambda left,right: pd.merge(left, right, left_index = True, right_index = True), dfs)

df_X = df_X.apply(lambda x: x.fillna(x.mean()),axis = 0) # Filling NaN values with the mean
df_Price = df_Price.apply(lambda x: x.fillna(x.mean()),axis = 0)

ss = StandardScaler()
df_X= ss.fit_transform(df_X)
df_X = pd.DataFrame(df_X)

number_train = int (0.7 * len(df_X))

train_x, train_y = df_X.iloc[:number_train], df_Price.iloc[:number_train]
test_x, test_y = df_X.iloc[number_train:], df_Price.iloc[number_train:]


regr = linear_model.Lasso(alpha = 9, normalize= False)
regr.fit(train_x,train_y)

train_perf = r2_score(train_y, regr.predict(train_x))
test_perf = r2_score(test_y, regr.predict(test_x))

train_MSE = mean_squared_error(train_y, regr.predict(train_x))
test_MSE = mean_squared_error(test_y, regr.predict(test_x))

print("MSE of Train data is %.4f" %(train_MSE))
print("MSE of test data is %.4f" %(test_MSE))
print("R2 of Train data is %.4f" %(train_perf))
print("R2 of Test data is %.4f" %(test_perf))

regr.coef_
# Out:
# MSE of Train data is 4643.5478
# MSE of test data is 10807.6145
# R2 of Train data is 0.9664
# R2 of Test data is 0.5725
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:28: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:29: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:30: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# ...

# %% [markdown]
# #### We performed a Lasso Regression using our data separated by cities. We sorted the data by the list called 'cities' first, then we merged them into one DataFrame. And since there were some cities with NaN values in some columns, we filled them up with there mean value. Later we scaled the data using StandardScaler. Finally, we tried to find the optinal alpha value for Lasso Regression and it turned out to be alpha = 9. As a result, the resulted coefficient shows that 'The number of population between 0 and 4' is the most important factor. And it's followed by 'The portion of Agricultural career' and 'The number of population between 5 and 14'.

# %% [markdown]
# #### From our data, especially graph 1, we can see that from the 10-year period from 2006-2016, there has been an overall rise in income. Although there is a huge dip in income starting from 2008 due to the housing contract, we see a gradual income increase since 2012. From this data, we can assume that the areas around San Diego definitely attract people of higher income. The data is accurate since San Diego is close to the beach. The higher income reflects the location and property value. From Graph 6, we can easily the distribution of wealth in different parts of the San Diego County. In the graph, we can see that the North Central region and North Inland area has the wealthiest people. North Central Area have families with a median income of 87,963 while North Inland Area have families with a median income of 79,116. The redevelopment of the two areas mentioned earlier led to the increase of wealthier families. The lowest income area is the Central Region which had a median income of 53,523.
#
# #### Graph 2 looks more closely at the differences of population. From the data we collected, we can see that the three highest populated cities in San Diego county includes San Diego, Chula Vista, and Oceanside. San Diego has the biggest population of over 1.2 million people. This beats the second highest populated city, Chula Vista, by great margins of almost 1 million individuals.
#
# #### Graph 3 consists of the age of the San Diego County. From this graph, we are able to see that the highest population is the age group between 25-44 for all the cities. This is because of the high amount of families/parents that are residing in this region. Lastly, we want to examine the graphs that look at ethnicity/race around the San Diego County. North Central region has the highest amount of Caucasians and Asians compared to the rest of the regions. We also see that there is a high number of Hispanics in Central and South Regions, while there isn’t very many Hispanics in North Central. So clearly we see there is a disparity and a preference where people choose to live and who they choose to live next to.

# %% [markdown]
# # Ethics and Privacy

# %% [markdown]
# #### The main use of our data is to understand how people look for ideal housing around the San Diego County. Although not perfect, we strive to create a projection that can show where a certain demographic or population may live in. To do this, we take in consideration of race, age, and income. The target group we aim for are usually students or new families trying to find residency around San Diego. A side effect of this categorization of demographics can lead to stigmatization. Stigmatization is the act of categorizing and giving a title to a person or group that leads to stereotyping or other connotations. Some people may not want to be categorized by race or income or even be labeled so this can be a potential ethical issue. One way to reduce this effect is to make sure we clarify that not everyone living in the area is the specific income, race, or age. The projection is based off of the average or the majority of the people living there.
# #### Another ethical issue that can be brought up is that some people are protective of how much they are paying for their living space. Many people consider their living area or house to be a private area or space, and would not like other people to see their information. Furthermore, observations toward these details might not be warranted. This again can be solved with the emphasis on the average of the income. The projection does not show the exact rent/payment for each household so there is privacy for the individual households.
# #### As we talked about above, stigmatization is unfortunate bi-product of this type of study. However the question asked is one that many people think in reality when moving into a city and data like this can allow people to understand the area they live in and who else lives around them. Most of the data itself was provided by the Census Bureau, a government funded group that is tasked with collecting data on the American People and the US economy. We would think this data is unbiased and nonpartisan as this is just a direct survey and observation of the people and institutions of the US. Another dataset was provided by SANDAG, a research and city-planning committee specifically for San Diego. If anything there could be some bias as they are collecting data on themselves, but something that would relatively rare as they are trying to help, and any data, bad or good, would be able to help. After reviewing the data we used and reviewing the analysis, we could say there is a possibility of bias as we were looking for data to help us with our hypothesis and not necessarily taking the neutral route and looking for data on both sides of the argument.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### Ultimately, we decided to explore the region of the greater San Diego and visualize how the characterization of the area has changed in terms of the socio-economic values of people. To observe the changes of the socio-economic environment of the San Diego county, we selected factors that may display this data. Our factors were age, income, and race. We inferred that these factors would play a significant role in the movement of the population in San Diego. We hypothesized that there would be correlations between the factors and the locations of the population. To better analyze the data and visualize the population movement , we separated the area around San Diego County to multiple regions. Basing our research on multiple censuses and SANDAG, pertaining to factors, we concluded that there has been a rise in the overall income in San Diego from 2006 to 2016. There was a drop in income in 2008; however, this did not prevent the gradual rise of income since 2012. We inferred from this data that the areas around San Diego has a growing population of people of higher income. We assumed this as San Diego is near the beach and the higher income is reflective of the location and the property value. The wealthiest people were congreated in the North Central and North inland region which are areas that have been redeveloped. The median income of the region was 87,963 and 79,116, respectively while the lowest median income at 53,523 was the Central Region. Seeing the movement of the population, we found that the largest population resided in San Diego, Chula Vista, and Oceanside. The largest age group in San Diego is those from ages 25-44. We credit this as a result of the high number of families occupying the region. From our research and graphs, we extracted the racial diversity around the San Diego County and deduced that the North Central region had the highest number of Caucasians and Asians compared to the other regions while a high number of Hispanics lived in Central and South regions. In summary, our data displays that there is a clear disparity and a preference where people choose to live and that many factors play into this decision.
#
# #### In our project, there are possible improvements and different approaches that we may have taken if we addressed this question again. One mishap was the initial bias that we had entering the research. Living as college students, we had an initial idea and bias of how the population around San Diego is congregated so while searching for data, our research may have segregated itself to find articles and data that proved our hypothesis and possibly inflated our data to adjust to our preferred conclusion. We could have improved on approaching our research from a more neutral ground. We would have asked more neutral questions in our search for data. This would be an improvement as it could potentially lead to a more neutral conclusion. Another change that would exist if we took on this question and research again would be our understanding of GitHub. While utilizing github, we encountered many issues within github that forced us to restart the data and the analysis. This improvement would pave a way for a cleaner data where we would have had many more datasets that could have potentially improved our research. Understanding github at a better level would make our process simpler and easier.
