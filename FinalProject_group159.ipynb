# %% [markdown]
# # Cogs 108 - Final Project

# %% [markdown]
# ## Overview

# %% [markdown]
# UFO sightings have long been a source of intrigue in popular culture. From alien encounters to covert
# military operations there are many theories regarding the various sources of these sighting reports. Since 1969,
# the National UFO Reporting Center has documented over 100,000 UFO sightings. We hope to demystify this
# phenomenon with a thorough analysis of these UFO sightings in relation to common socioeconomic
# indicators (educational attainment and unemployment). If correlations can be found between UFO sighting report frequency and education / unemployment, perhaps some light might be shed on the origin these sightings.

# %% [markdown]
# ## Names
#
# - Nicholas Paz
# - Christopher Wong
# - Wesley Ruan
# - Timothy Nordahl

# %% [markdown]
# ## Research Question

# %% [markdown]
# In an arbitrary county in California, is there a relationship between the frequency of UFO sighting reports and educational attainment / unemployment rates?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Background:
# This question was of interest to our group because we all shared a fascination with science fiction, specifically the paranormal. When the idea of using UFO sightings came up, we all wanted to determine what, generally speaking, causes people to report UFO sightings. While brainstorming we all agreed that education and employment would be the most likely causes for the as a form of escapism in belief or misinterpretation of what is observed above and our project hypothesis was born as we attempted to prove just that.
#
# Prior Work:
# https://www.psychologytoday.com/us/blog/fulfillment-any-age/201206/what-psychology-can-tell-you-about-your-extraterrestrial-beliefs
# https://theconversation.com/why-are-people-starting-to-believe-in-ufos-again-61717
#
# Both of the articles linked above reference surveys and scholarly articles utilizing surveys highly relevant to the question we have outlined that we are, unfortunately, unable to access without purchasing them.
# The first article by Psychology Today discusses two studies performed by Viren Swami, Adrian Furnham, Tanja Haubner, Stefan Stieger, J. Pietschnig, & Martin Voracek measuring people's beliefs on 37 extraterrestrial topics across almost 600 people in Britain and Austria in the first study and measuring correlation between extraterrestrial beliefs paranormal beliefs, superstition, schizotypy, and demographics across over 400 people in the second study. The results of these studies, according to Psychology Today, indicate that belief in extraterrestrials is highly correspondent with political beliefs, religious beliefs, and those with more education were less likely to believe.
#
# The second article by The Conversation discusses a scholarly article authored by Christopher D. Bader, Joseph O. Baker, and F. Carson Mencken discussing the paranormal as it relates to American religion and culture. Their findings indicated that those more socially connected are less likely to report paranormal belief, as are those who receive lower income as opposed higher income.
#
# Both of these articles attempt to answer our question using survey responses from Americans and abroad rather than using data based on geographic regions as we did

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# ### Null Hypothesis
#
# There will not be a significant correlation between UFO sighting report frequency and educational attainment / unemployment.  As educational attainment rises and unemployment drops in a county, the frequency of UFO sighting reports will be unaffected.
#
# ### Alternate Hypothesis
#
# There will be a significant correlation between UFO sighting report frequency and educational attainment / unemployment.  As educational attainment rises and unemployment drops in a county, the frequency of UFO sighting reports will decrease.
#
# ## Prediction
#
# We predict that we will find a correlation between education / unemployment and the frequency of UFO sightings in a county.

# %% [markdown]
# ## Datasets

# %% [markdown]
# - NUFORC Reports
# - https://data.world/timothyrenner/ufo-sightings/workspace/file?filename=nuforc_reports.csv
# - 112,092 observations
#
# This dataset is an accumulation of the UFO sighting reports documented by the National UFO Reporting Center in roughly the last 40 years. For each sighting it contains information regarding the date, time, shape, duration, location, etc.
#
# - Educational attainment for the U.S., States, and counties, 1970-2017
# - https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/
# - 3288 observations
#
# This dataset contains information provided by the Economic Research Service regarding educational attainment statistics at a county level in the United States. It has stats on multiple levels of education; high school completion and higher learning.
#
# - Population estimates for the U.S., States, and counties, 2010-18
# - https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/
# - 3276 observations
#
# This dataset contains information provided by the Economic Research Service regarding population estimate statistics at a county level in the United States.
#
# - Unemployment and median household income for the U.S., States, and counties, 2007-18
# - https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/
# - 3283
#
# This dataset contains information provided by the Economic Research Service regarding unemployment statistics at a county level in the United States. It also contains some median household income statistics.
#
# Each of these datasets contains information that can be categorized at a county level. The goal of this project will be to create a single dataframe in which each county in California is associated with a frequency of UFO sighting reports as well as education and unemployment data. Conclusions will then be drawn from those observations. Population data will be used to normalize the frequency of UFO sighting reports for a given county.

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import itertools
from sklearn import linear_model
from sklearn.metrics import r2_score

sns.set()
sns.set_context('talk')
pd.set_option('precision', 2)

# %% [markdown]
# ## Data Cleaning

# %%
us_states=[
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", 
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", 
    "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", 
    "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", 
    "UT", "VT", "VA", "WA", "WV", "WI", "WY"
]
year_range = [2010,2011,2012,2013,2014,2015,2016]

# %%
# create a dictionary from CA cities to their respective counties
page_link = 'https://www.counties.org/cities-within-each-county'
page_response = requests.get(page_link, timeout=5)
page_content = BeautifulSoup(page_response.content, "html.parser")

ca_city_to_county = {}
ca_counties = [] 
current_county=page_content.find('h3')

for i in range(58):
    ca_counties.append(current_county.string.strip())
    next_county = current_county.next_sibling.next_sibling.next_sibling.next_sibling
    cities_in_county = current_county.next_sibling.next_sibling
    for city in cities_in_county:
        ca_city_to_county[city.string.strip()] = current_county.string.strip()
    current_county = next_county
_ = ca_city_to_county.pop('',None)

for i, county in enumerate(ca_counties):
    ca_counties[i] = county.replace('City & County','County')
    if 'County' not in county: ca_counties[i] += ' County'

# %%
# extract date from date_time column
def extract_year(str_in):
    date_string = str_in.split('T')[0]
    [year,month,day] = date_string.split('-')
    return int(year)

# extract month from date_time column
def extract_month(str_in):
    date_string = str_in.split('T')[0]
    [year,month,day] = date_string.split('-')
    return int(month)
    
# extract time of day from date_time column
def extract_time(str_in):
    time_string = str_in.split('T')[1]
    [hour,minute,second] = time_string.split(':')
    return float(hour) + float(minute) / 60

# get county from CA city
def get_county(str_in):
    try: return ca_city_to_county[str_in]
    except: return None

# %%
# Create California UFO Sighting Dataframe
df_ufo = pd.read_csv('nuforc_reports.csv')

# general cleaning
df_ufo = df_ufo.drop(columns=['summary','report_link','text','posted','stats'])
df_ufo = df_ufo.dropna()
df_ufo = df_ufo[df_ufo['state'].isin(us_states)]
df_ufo = df_ufo[df_ufo['city_longitude']<-60]
df_ufo = df_ufo[df_ufo['city_latitude']>0]

# create time and day columns
df_ufo['year'] = df_ufo['date_time'].apply(extract_year)
df_ufo['month'] = df_ufo['date_time'].apply(extract_month)
df_ufo['time'] = df_ufo['date_time'].apply(extract_time)

# create california df
df_ca = df_ufo[df_ufo['state']=='CA']
df_ca = df_ca[df_ca['year'].isin(year_range)]
df_ca['county'] = df_ca['city'].apply(get_county)
df_ca.dropna()

df_ca.head()
# Out:
#              city state            date_time   shape     duration  \
# 185   Los Angeles    CA  2014-11-30T15:30:00  sphere  2-3 minutes
# 666       Vallejo    CA  2013-06-30T00:00:00   other    2 minutes
# 825   Los Angeles    CA  2016-10-27T21:00:00    oval    2 minutes
# 896        Corona    CA  2012-04-18T21:00:00  circle      Seconds
# 1861      Atwater    CA  2015-11-05T16:00:00   light    4 seconds
#
#       city_latitude  city_longitude  year  month  time              county
# 185           34.05         -118.28  2014     11  15.5  Los Angeles County
# 666           38.12         -122.23  2013      6   0.0       Solano County
# 825           34.05         -118.28  2016     10  21.0  Los Angeles County
# 896           33.86         -117.58  2012      4  21.0    Riverside County
# 1861          37.35         -120.61  2015     11  16.0       Merced County

# %%
# Create California Unemployment Dataframe
df_ua = pd.read_excel('Unemployment.xls')
df_ua.columns = df_ua.iloc[6]
df_ua = df_ua[df_ua['State']=='CA']
df_ua['Area_name'] = df_ua['Area_name'].apply(lambda name: name.replace(', CA', '')) 
df_ua['Area_name'] = df_ua['Area_name'].apply(lambda name: name.replace('County/city', 'County')) 
df_ua = df_ua[df_ua['Area_name'].isin(ca_counties)]
df_ua.head()
# Out:
# 6    FIPS State         Area_name Rural_urban_continuum_code_2013  \
# 202  6001    CA    Alameda County                               1
# 203  6003    CA     Alpine County                               8
# 204  6005    CA     Amador County                               6
# 205  6007    CA      Butte County                               3
# 206  6009    CA  Calaveras County                               6
#
# 6   Urban_influence_code_2013 Metro_2013 Civilian_labor_force_2007  \
# 202                         1          1                    745198
# 203                         4          0                       493
# 204                         4          0                     17703
# 205                         2          1                    101228
# 206                         6          0                     20725
#
# 6   Employed_2007 Unemployed_2007 Unemployment_rate_2007  ...  \
# 202        710144           35054                    4.7  ...
# 203           454              39                    7.9  ...
# 204         16675            1028                    5.8  ...
# 205         94489            6739                    6.7  ...
# 206         19394            1331                    6.4  ...
#
# 6   Civilian_labor_force_2017 Employed_2017 Unemployed_2017  \
# 202                    840239        809372           30867
# 203                       550           516              34
# 204                     14727         13997             730
# 205                    102230         96327            5903
# 206                     21064         20070             994
#
# 6   Unemployment_rate_2017 Civilian_labor_force_2018 Employed_2018  \
# 202                    3.7                    848215        822769
# 203                    6.2                       547           522
# 204                      5                     14706         14117
# 205                    5.8                    102712         97619
# 206                    4.7                     21351         20506
#
# 6   Unemployed_2018 Unemployment_rate_2018 Median_Household_Income_2017  \
# 202           25446                      3                        95550
# 203              25                    4.6                        55755
# 204             589                      4                        60588
# 205            5093                      5                        48634
# 206             845                      4                        58536
#
# 6   Med_HH_Income_Percent_of_State_Total_2017
# 202                                   1.3e+02
# 203                                        78
# 204                                        84
# 205                                        68
# 206                                        82
#
# [5 rows x 56 columns]

# %%
# Creat California Educational Attainment Dataframe
df_ed = pd.read_excel('Education.xls')
df_ed.columns = df_ed.iloc[3] 
df_ed = df_ed[df_ed['State']=='CA']
df_ed = df_ed[df_ed['Area name'].isin(ca_counties)]
df_ed.head()
# Out:
# 3   FIPS Code State         Area name 2003 Rural-urban Continuum Code  \
# 203     06001    CA    Alameda County                               1
# 204     06003    CA     Alpine County                               8
# 205     06005    CA     Amador County                               6
# 206     06007    CA      Butte County                               3
# 207     06009    CA  Calaveras County                               6
#
# 3   2003 Urban Influence Code 2013 Rural-urban Continuum Code  \
# 203                         1                               1
# 204                         4                               8
# 205                         4                               6
# 206                         2                               3
# 207                         6                               6
#
# 3   2013 Urban Influence Code Less than a high school diploma, 1970  \
# 203                         1                                217589
# 204                         4                                   101
# 205                         4                                  2911
# 206                         2                                 24482
# 207                         6                                  4164
#
# 3   High school diploma only, 1970 Some college (1-3 years), 1970  ...  \
# 203                         197371                          87675  ...
# 204                             98                             57  ...
# 205                           2314                           1214  ...
# 206                          17743                           8511  ...
# 207                           2721                           1127  ...
#
# 3   Percent of adults completing some college or associate's degree, 2000  \
# 203                                                 28
# 204                                                 34
# 205                                                 37
# 206                                                 36
# 207                                                 40
#
# 3   Percent of adults with a bachelor's degree or higher, 2000  \
# 203                                                 35
# 204                                                 28
# 205                                                 17
# 206                                                 22
# 207                                                 17
#
# 3   Less than a high school diploma, 2013-17  \
# 203                                   141961
# 204                                       83
# 205                                     2978
# 206                                    16411
# 207                                     3421
#
# 3   High school diploma only, 2013-17  \
# 203                            203796
# 204                               277
# 205                              7832
# 206                             33023
# 207                              9450
#
# 3   Some college or associate's degree, 2013-17  \
# 203                                      284098
# 204                                         243
# 205                                       11745
# 206                                       57637
# 207                                       14775
#
# 3   Bachelor's degree or higher, 2013-17  \
# 203                               509294
# 204                                  208
# 205                                 6398
# 206                                38847
# 207                                 6604
#
# 3   Percent of adults with less than a high school diploma, 2013-17  \
# 203                                                 12
# 204                                                 10
# 205                                                 10
# 206                                                 11
# 207                                                 10
#
# 3   Percent of adults with a high school diploma only, 2013-17  \
# 203                                                 18
# 204                                                 34
# 205                                                 27
# 206                                                 23
# 207                                                 28
#
# 3   Percent of adults completing some college or associate's degree, 2013-17  \
# 203                                                 25
# 204                                                 30
# 205                                                 41
# 206                                                 40
# 207                                                 43
#
# 3   Percent of adults with a bachelor's degree or higher, 2013-17
# 203                                                 45
# 204                                                 26
# 205                                                 22
# 206                                                 27
# 207                                                 19
#
# [5 rows x 47 columns]

# %%
# Create California Population Dataframe
df_pop = pd.read_excel('PopulationEstimates.xls')
df_pop.columns = df_pop.iloc[1]
df_pop = df_pop[df_pop['State']=='CA']
df_pop = df_pop[df_pop['Area_Name'].isin(ca_counties)]
df_pop.head()
# Out:
# 1     FIPS State         Area_Name Rural-urban_Continuum Code_2003  \
# 194  06001    CA    Alameda County                               1
# 195  06003    CA     Alpine County                               8
# 196  06005    CA     Amador County                               6
# 197  06007    CA      Butte County                               3
# 198  06009    CA  Calaveras County                               6
#
# 1   Rural-urban_Continuum Code_2013 Urban_Influence_Code_2003  \
# 194                               1                         1
# 195                               8                         4
# 196                               6                         4
# 197                               3                         2
# 198                               6                         6
#
# 1   Urban_Influence_Code_2013 Economic_typology_2015 CENSUS_2010_POP  \
# 194                         1                      0         1510271
# 195                         4                      5            1175
# 196                         4                      4           38091
# 197                         2                      0          220000
# 198                         6                      5           45578
#
# 1   ESTIMATES_BASE_2010  ... R_DOMESTIC_MIG_2017 R_DOMESTIC_MIG_2018  \
# 194             1510258  ...                -7.1                  -6
# 195                1175  ...                  61                 -21
# 196               38091  ...                  32                  24
# 197              220002  ...                  10                 7.3
# 198               45578  ...                  10                   2
#
# 1   R_NET_MIG_2011 R_NET_MIG_2012 R_NET_MIG_2013 R_NET_MIG_2014  \
# 194            5.2            8.7             10             11
# 195            -59             15             16            -42
# 196           -4.5           -7.9           -8.5            6.7
# 197             -1            3.6            3.5            7.1
# 198           -4.2           -5.4           0.78            2.8
#
# 1   R_NET_MIG_2015 R_NET_MIG_2016 R_NET_MIG_2017 R_NET_MIG_2018
# 194             10            3.6          -0.53           0.41
# 195            1.8            -23             61            -21
# 196             12             14             32             25
# 197            4.9            7.3             11            8.5
# 198            8.9             11             11            2.6
#
# [5 rows x 149 columns]

# %% [markdown]
# ## Data Visualization

# %%
# Visualize California UFO Sightings

# Create scatter plot of city coordinates in CA
df_ca.plot(
    kind='scatter',
    x='city_longitude',
    y='city_latitude',
    figsize=(10,15),
    title='Location of Reports (California)'
);plt.show()

# Create bar graph of UFO sighting reports per county
df_ca['county'].value_counts().plot(
    kind='bar',
    figsize=(20,10),
    title='Reports by County (California)'
);plt.show()

# Create bar graph of reported shapes of UFOs sighted in CA
df_ca['shape'].value_counts().plot(
    kind='bar',
    figsize=(20,10),
    title='UFO Shape (California)'
);plt.show()

# Create a histogram of time of day of reported UFO sightings in CA
df_ca['time'].plot(
    kind='hist',
    bins=48,
    figsize=(20,10),
    title='Time of Sighting (California)'
);plt.show()

# Create a bar graph of UFO sightings in CA by year since 2010
df_ca['year'].value_counts().sort_index().plot(
    kind='bar',
    sort_columns=True,
    figsize=(20,10),
    title='Reports by Year (California)'
);plt.show()

# Create a bar graph of UFO sightings in CA by month
df_ca['month'].value_counts().sort_index().plot(
    kind='bar',
    sort_columns=True,
    figsize=(20,10),
    title='Reports by Month (California)'
);plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# We will use county level data to create bivariate data points. We will compare ufo sighting frequncy with educational attainment and with unemployment. Then using logistic regression we will attempt to find correlations between our variables

# %%
# get the pop estimate of a county from a year
def get_pop_estimate(row):
    r = df_pop.loc[df_pop['Area_Name']==row['county']]
    return r['POP_ESTIMATE_'+str(row['year'])].tolist()[0]

# get the number of ufo sightings from a county from a year
def get_sightings_num(row):
    sightings = df_ca[(df_ca['county']==row['county']) & (df_ca['year']==row['year'])]
    return sightings.shape[0]

def get_unemployment(row):
    r = df_ua.loc[df_ua['Area_name']==row['county']]
    return r['Unemployment_rate_'+str(row['year'])].tolist()[0]

def get_education(row):
    r = df_ed.loc[df_ed['Area name']==row['county']]
    return 100.0 - r['Percent of adults with less than a high school diploma, 2013-17'].tolist()[0]

# %%
# create analysis dataframe
df_anal = pd.DataFrame()
df_anal['county'] = ca_counties * len(year_range)
df_anal['year'] = list(itertools.chain.from_iterable([[year] * len(ca_counties) for year in year_range]))
df_anal['pop'] = df_anal.apply(get_pop_estimate,axis=1)
df_anal['sightings'] = df_anal.apply(get_sightings_num,axis=1)
df_anal['sightings per cap x 100,000'] = df_anal.apply(lambda row:(row['sightings'] / row['pop'])*100000,axis=1)
df_anal['unemployment'] = df_anal.apply(get_unemployment,axis=1)
df_anal['education'] = df_anal.apply(get_education,axis=1)
df_anal = df_anal[df_anal['sightings']!=0]
degrees_freedom = df_anal.shape[0] - 2
df_anal.head()
# Out:
#                 county  year      pop  sightings  sightings per cap x 100,000  \
# 0       Alameda County  2010  1513043         17                         1.12
# 2        Amador County  2010    37884          1                         2.64
# 3         Butte County  2010   219945          2                         0.91
# 5        Colusa County  2010    21437          1                         4.66
# 6  Contra Costa County  2010  1052559         15                         1.43
#
#    unemployment  education
# 0          10.9       87.5
# 2          14.1       89.7
# 3          13.9       88.8
# 5          20.8       69.4
# 6          11.0       89.1

# %%
# plot relationships between UFO sightings per capita and uemployment / education
df_anal.plot(
    kind='scatter',
    x='sightings per cap x 100,000',
    y='unemployment',
    figsize=(20,10),
    title='UFO Sightings per Capita vs. Unemployment Percentage'
);plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# The above scatter plot shows unemployment plotted with sightings per capita x 100,000. From the scatter plot, its difficult to determine correlation. While unclear, we can see a higher density of lower values for unemployment and lower values for UFO sightings. While no pattern is readily discernible from the graph, correlation cannot be determined definitively without greater numerical analysis.

# %%
df_anal.plot(
    kind='scatter',
    x='sightings per cap x 100,000',
    y='education',
    figsize=(20,10),
    title='UFO Sightings per Capita vs. Educational Attainment'
);plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# The above scatter plot shows education plotted with sightings per capita x 100,000. From the scatter plot, its difficult to determine correlation, however, a positive correlation may be possible such that as the value for education increases, sightings per capita increase as well, despite the generally heavier density towards greater educational attainment.

# %%
X = df_anal['sightings per cap x 100,000'].values.reshape(-1,1)
Y = df_anal['unemployment'].values
regr = linear_model.LinearRegression().fit(X,Y)
pred = regr.predict(X)

plt.scatter(X, Y,  color='black')
plt.plot(X, pred, color='blue', linewidth=3)

print("y = %s * x + %d" % (regr.coef_[0], regr.intercept_))
print("r^2 = " + str(r2_score(Y, pred)))
print("pearson correlation coefficient: " + str(df_anal['sightings per cap x 100,000'].corr(df_anal['unemployment'])))
# Out:
# y = 0.006769214959296644 * x + 10
# r^2 = 8.625566597530998e-06
# pearson correlation coefficient: 0.0029369314934846098

# %% [markdown]
# The above scatter plot shows unemployment plotted with sightings per capita x 100,000, the line plotted shows the best fit line to the scatter plot. From the scatter plot, its difficult to determine correlation, however with the best fit line, we can see that correlation between the two is unlikely, though its this cannot be determined definitively without greater numerical analysis

# %%
X = df_anal['sightings per cap x 100,000'].values.reshape(-1,1)
Y = df_anal['education'].values
regr = linear_model.LinearRegression().fit(X,Y)
pred = regr.predict(X)

plt.scatter(X, Y,  color='black')
plt.plot(X, pred, color='blue', linewidth=3)

print("y = %s * x + %d" % (regr.coef_[0], regr.intercept_))
print("r^2 = " + str(r2_score(Y, pred)))
print("pearson correlation coefficient: " + str(df_anal['sightings per cap x 100,000'].corr(df_anal['education'])))
# Out:
# y = 0.31168125256126417 * x + 82
# r^2 = 0.006341076318498562
# pearson correlation coefficient: 0.07963087540959714

# %% [markdown]
# The above scatter plot shows education plotted with sightings per capita x 100,000, the line plotted shows the best fit line to the scatter plot. From the scatter plot, its difficult to determine correlation, however with the best fit line, we can see that there may be a correlation between the two, though its significance cannot be determined without greater numerical analysis

# %% [markdown]
# Here we used linear regression to find if there is a statistically significant correlation between both unemployment values and education values and the UFO sightings per capita (multiplied by 100,000). We use linear regression because we expect a linear relationship between unemployment and UFO sightings as well as between education and UFO sightings (as unemployment goes up and educational attainment goes down, we expect UFO sightings to rise). To do so, we utilize the regression to find the best fit line for the data, the variance for the data, and the pearson correlation coefficient. The correlation coefficient shows the linear correlation between unemployment/education and UFO sightings while variance explains what percent of the data can be explained by the explained by the correlation coefficent. Using these variables we can find r-critical, which r must exceed to reject the null hypothesis for both sets of analysis

# %% [markdown]
# ## Results

# %% [markdown]
# ### UFO Sighting Frequency and Unemployment - Fail to Reject Null Hypothesis
#
# - n = 292.
# - df = 290
# - r-critical = 0.115
# - r-value = 0.0029369314934846098
#
# ### UFO Sighting Frequency and Educational Attainment - Fail to Reject Null Hypothesis
#
# - n = 292.
# - df = 290
# - r-critical = 0.115
# - r-value = 0.07963087540959714
#
#
# In the case of both tests, the resulting r value is less than the r critical for a two-tailed hypothesis with an alpha of 0.05. Therefore we fail to reject our null hypothesis for both cases. It appears that there is not a detectable correlation between ufo sighting frequency and either unemployment or educational attainment rates per county.

# %% [markdown]
# ## Ethics and Privacy

# %% [markdown]
# For this project, there are minimal ethical considerations. UFO sightings are deemed trivial by society and
# while interesting, probably are not of much importance. This project further does not deal with information regarding individual people.
#
# When we first came across this dataset we knew that even though it was the public record we still had to be careful about how we would utilize the information and present our findings. Even though public data is usually seen as low-threat, we were still aware of the possibility that sometimes publishing data on certain communities can lead to some consequences. This can lead to violating respect for communities and respect for persons -- which is also reiterated in the Belmont report. Regardless of the data — it can still lead to biases and how people interact with the place(s) that are discussed. However, since it is a public record there are not many other barriers of ethical consideration for specific interest groups that our group needs to worry about in the scope of our project.

# %% [markdown]
# ## Conclusion and Discussion

# %% [markdown]
# This project sought to eplore the data provided by the NUFORC regarding UFO sighting reports. In particular we investigated the relationships between the frequency of UFO sightings and socioeconomic indicators (education and unemployment). By Looking at California at a county level, we were able to produce a sizable sample of bivariate data points. Using logistic regression, we performed a hypothesis test.
#
# With n = 292, 290 degrees of freedom, and an r-critical value of 0.115 we failed to reject the null hypothesis since the R-values were r = 0.07963087540959714  and  r = 0.0029369314934846098 respectively. This analysis of our dataset led us to conclude that UFO sightings likely do not have a significant correlation to educational attainment and unemployment in California.
#
# It is important to note that there were some possible confounds with our dataset. For example, one of the confounds was that the data is only limited to populations within the state of California. Ideally, if we had more time we would like to diversify the data in order to hopefully generate results that are applicable to the entire population instead of a small niche.
